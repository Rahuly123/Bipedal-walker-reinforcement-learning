# %% [markdown]
# # BipedalWalker-v2 with PPO, Vectorized Environment
# In this notebook, you will implement a PPO agent with OpenAI Gym's BipedalWalker-v2 environment.
#
# ### 1. Create Vectorized Environment

# %%
import gym
import random
import torch
import numpy as np
from collections import deque
import matplotlib.pyplot as plt

from  collections  import deque
import time
from model import Policy
from ppo import ppo_agent
from storage import RolloutStorage
from utils import get_render_func, get_vec_normalize
from envs import make_vec_envs
from parallelEnv import parallelEnv
import matplotlib.pyplot as plt
# %matplotlib inline

print('gym version: ', gym.__version__)
print('torch version: ', torch.__version__)

seed = 0 
gamma=0.99
num_processes=16 
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print('device: ', device)

envs = parallelEnv('BipedalWalker-v3', n=num_processes, seed=seed)

## make_vec_envs -cannot find context for 'forkserver'
## forkserver is only available in Python 3.4+ and only on some Unix platforms (not on Windows).
## envs = make_vec_envs('BipedalWalker-v2', \
##                    seed + 1000, num_processes,
##                    None, None, False, device='cpu', allow_early_resets=False)

max_steps = envs.max_steps
print('max_steps: ', max_steps)

torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
np.random.seed(seed)
# Out:
# gym version:  0.19.0
# torch version:  1.10.2+cpu
# device:  cpu
# max_steps:  1600

# %% [markdown]
# ### 2. Instantiate Model, Agent and Storage
#
# Initialize the Policy (model MLPBase), PPO Agent and Rollout Storage.

# %%
## model Policy uses MLPBase
policy = Policy(envs.observation_space.shape, envs.action_space,\
        base_kwargs={'recurrent': False})

policy.to(device)

agent = ppo_agent(actor_critic=policy, ppo_epoch=16, num_mini_batch=16,\
                lr=0.001, eps=1e-5, max_grad_norm=0.5)

rollouts = RolloutStorage(num_steps=max_steps, num_processes=num_processes, \
                        obs_shape=envs.observation_space.shape, action_space=envs.action_space, \
                        recurrent_hidden_state_size=policy.recurrent_hidden_state_size)

obs = envs.reset()
print('type obs: ', type(obs), ', shape obs: ', obs.shape)
obs_t = torch.tensor(obs)
print('type obs_t: ', type(obs_t), ', shape obs_t: ', obs_t.shape)

rollouts.obs[0].copy_(obs_t)
rollouts.to(device)
# Out:
# type obs:  <class 'numpy.ndarray'> , shape obs:  (16, 24)
# type obs_t:  <class 'torch.Tensor'> , shape obs_t:  torch.Size([16, 24])

# %% [markdown]
# ### 3.Save model function

# %%
def save(model, directory, filename, suffix):
    torch.save(model.base.actor.state_dict(), '%s/%s_actor_%s.pth' % (directory, filename, suffix))
    torch.save(model.base.critic.state_dict(), '%s/%s_critic_%s.pth' % (directory, filename, suffix))
    torch.save(model.base.critic_linear.state_dict(), '%s/%s_critic_linear_%s.pth' % (directory, filename, suffix))
    
limits = [-300, -160, -100, -70, -50, 0, 20, 30, 40, 60, 90, 120, 150, 180, 210, 240, 270, 300, 330]

def return_suffix(j):
    suf = '0'
    for i in range(len(limits)-1):
        if j > limits[i] and j < limits[i+1]:
            suf = str(limits[i+1])
            break
        
        i_last = len(limits)-1    
        if  j > limits[i_last]:
            suf = str(limits[i_last])
            break
    return suf

# %% [markdown]
# ### 4. Train the Agent  with Vectorized Environment

# %%
num_updates=1000000
gamma = 0.99
tau=0.95
save_interval=30
log_interval= 1 

def ppo_vec_env_train(envs, agent, policy, num_processes, num_steps, rollouts):
    
    time_start = time.time()
    
    n=len(envs.ps)    
    envs.reset()
    
    # start all parallel agents
    print('Number of agents: ', n)
    envs.step([[1]*4]*n)
    
    indices = []
    for i  in range(n):
        indices.append(i)
     
    s = 0
    
    scores_deque = deque(maxlen=100)
    scores_array = []
    avg_scores_array = []    

    for i_episode in range(num_updates):
        
        total_reward = np.zeros(n)
        timestep = 0
        
        for timestep in range(num_steps):

            with torch.no_grad():
                value, actions, action_log_prob, recurrent_hidden_states = \
                   policy.act(
                        rollouts.obs[timestep],
                        rollouts.recurrent_hidden_states[timestep],
                        rollouts.masks[timestep])
                
            obs, rewards, done, infos = envs.step(actions.cpu().detach().numpy())
            
            total_reward += rewards  ## this is the list by agents
                        
            # If done then clean the history of observations.
            masks = torch.FloatTensor([[0.0] if done_ else [1.0] for done_ in done])
            obs_t = torch.tensor(obs)
            ## Add one dimnesion to tensor, otherwise does not work
            ## This is (unsqueeze(1)) solution for:
            ## RuntimeError: The expanded size of the tensor (1) must match the existing size...
            rewards_t = torch.tensor(rewards).unsqueeze(1)
            rollouts.insert(obs_t, recurrent_hidden_states, actions, action_log_prob, \
                value, rewards_t, masks)
                    
        avg_total_reward = np.mean(total_reward)
        scores_deque.append(avg_total_reward)
        scores_array.append(avg_total_reward)
                
        with torch.no_grad():
            next_value = policy.get_value(rollouts.obs[-1],
                            rollouts.recurrent_hidden_states[-1],
                            rollouts.masks[-1]).detach()

        rollouts.compute_returns(next_value, gamma, tau)

        agent.update(rollouts)

        rollouts.after_update()
        
        avg_score = np.mean(scores_deque)
        avg_scores_array.append(avg_score)

        if i_episode > 0 and i_episode % save_interval == 0:
            print('Saving model, i_episode: ', i_episode, '\n')
            suf = return_suffix(avg_score)
            save(policy, 'dir_save', 'we0', suf)
            #save_venv(policy, 'dir_save_VecEnv', 'final')

        
        if i_episode % log_interval == 0 and len(scores_deque) > 1:            
            prev_s = s
            s = (int)(time.time() - time_start)
            t_del = s - prev_s
            print('Ep. {}, Timesteps {}, Score.Agents: {:.2f}, Avg.Score: {:.2f}, Time: {:02}:{:02}:{:02}, \
Interval: {:02}:{:02}'\
                   .format(i_episode, timestep+1, \
                        avg_total_reward, avg_score, s//3600, s%3600//60, s%60, t_del%3600//60, t_del%60)) 
    
        if len(scores_deque) == 100 and np.mean(scores_deque) > 300.5:   
        # if np.mean(scores_deque) > 20:   
            print('Environment solved with Average Score: ',  np.mean(scores_deque) )
            break
    
    
    return scores_array, avg_scores_array

# %%
# import time
# from collections import deque
# import numpy as np
# import torch

# def ppo_vec_env_train(envs, agent, policy, num_processes, num_steps, rollouts, num_updates=1000000, gamma=0.99, tau=0.95, save_interval=30, log_interval=1):
#     time_start = time.time()
    
#     n = len(envs.ps)    
#     envs.reset()
    
#     print('Number of agents: ', n)
#     envs.step([[1]*4]*n)
     
#     s = 0
#     scores_deque = deque(maxlen=100)
#     scores_array = []
#     avg_scores_array = []    

#     for i_episode in range(num_updates):
#         # total_reward = np.zeros(n)
#         total_reward = []
#         timestep = 0
                
#         for timestep in range(num_steps):

#             with torch.no_grad():
#                 value, actions, action_log_prob, recurrent_hidden_states = policy.act(
#                     rollouts.obs[timestep],
#                     rollouts.recurrent_hidden_states[timestep],
#                     rollouts.masks[timestep]
#                 )
                
#             obs, rewards, done, infos = envs.step(actions.cpu().detach().numpy())
            
#             envs.render(mode='human')  # Render the environment, 'human' mode usually shows a window

#             total_reward += rewards  ## this is the list by agents
                        
#             masks = torch.FloatTensor([[0.0] if done_ else [1.0] for done_ in done])
#             obs_t = torch.tensor(obs)
#             rewards_t = torch.tensor(rewards).unsqueeze(1)
#             rollouts.insert(obs_t, recurrent_hidden_states, actions, action_log_prob, value, rewards_t, masks)
                    
#         avg_total_reward = np.mean(total_reward)
#         scores_deque.append(avg_total_reward)
#         scores_array.append(avg_total_reward)
                
#         with torch.no_grad():
#             next_value = policy.get_value(rollouts.obs[-1],
#                                           rollouts.recurrent_hidden_states[-1],
#                                           rollouts.masks[-1]).detach()

#         rollouts.compute_returns(next_value, gamma, tau)

#         agent.update(rollouts)

#         rollouts.after_update()
        
#         avg_score = np.mean(scores_deque)
#         avg_scores_array.append(avg_score)

#         if i_episode > 0 and i_episode % save_interval == 0:
#             print('Saving model, i_episode: ', i_episode, '\n')
#             suf = return_suffix(avg_score)
#             save(policy, 'dir_save', 'we0', suf)
        
#         if i_episode % log_interval == 0 and len(scores_deque) > 1:            
#             prev_s = s
#             s = (int)(time.time() - time_start)
#             t_del = s - prev_s
#             print(f'Ep. {i_episode}, Timesteps {timestep+1}, Score.Agents: {avg_total_reward:.2f}, Avg.Score: {avg_score:.2f}, Time: {s//3600:02}:{s%3600//60:02}:{s%60:02}, Interval: {t_del%3600//60:02}:{t_del%60:02}') 
    
#         if len(scores_deque) == 100 and np.mean(scores_deque) > 300.5:   
#             print('Environment solved with Average Score: ',  np.mean(scores_deque) )
#             break
    
#     return scores_array, avg_scores_array

# %%
scores, avg_scores = ppo_vec_env_train(envs, agent, policy, num_processes, max_steps, rollouts)
# Out:
# Number of agents:  16
# Ep. 1, Timesteps 1600, Score.Agents: -895.92, Avg.Score: -924.58, Time: 00:00:16, Interval: 00:16
# Ep. 2, Timesteps 1600, Score.Agents: -484.93, Avg.Score: -778.03, Time: 00:00:24, Interval: 00:08
# Ep. 3, Timesteps 1600, Score.Agents: -368.04, Avg.Score: -675.54, Time: 00:00:31, Interval: 00:07
# Ep. 4, Timesteps 1600, Score.Agents: -278.47, Avg.Score: -596.12, Time: 00:00:38, Interval: 00:07
# Ep. 5, Timesteps 1600, Score.Agents: -270.33, Avg.Score: -541.82, Time: 00:00:52, Interval: 00:14
# Ep. 6, Timesteps 1600, Score.Agents: -168.23, Avg.Score: -488.45, Time: 00:01:14, Interval: 00:22
# Ep. 7, Timesteps 1600, Score.Agents: -187.27, Avg.Score: -450.80, Time: 00:01:36, Interval: 00:22
# Ep. 8, Timesteps 1600, Score.Agents: -179.89, Avg.Score: -420.70, Time: 00:01:56, Interval: 00:20
# Ep. 9, Timesteps 1600, Score.Agents: -203.85, Avg.Score: -399.02, Time: 00:02:15, Interval: 00:19
# Ep. 10, Timesteps 1600, Score.Agents: -117.97, Avg.Score: -373.47, Time: 00:02:36, Interval: 00:21
# Ep. 11, Timesteps 1600, Score.Agents: -143.99, Avg.Score: -354.34, Time: 00:02:56, Interval: 00:20
# Ep. 12, Timesteps 1600, Score.Agents: -125.68, Avg.Score: -336.75, Time: 00:03:08, Interval: 00:12
# Ep. 13, Timesteps 1600, Score.Agents: -177.50, Avg.Score: -325.38, Time: 00:03:15, Interval: 00:07
# Ep. 14, Timesteps 1600, Score.Agents: -157.47, Avg.Score: -314.18, Time: 00:03:23, Interval: 00:08
# Ep. 15, Timesteps 1600, Score.Agents: -116.98, Avg.Score: -301.86, Time: 00:03:30, Interval: 00:07
# Ep. 16, Timesteps 1600, Score.Agents: -104.07, Avg.Score: -290.22, Time: 00:03:38, Interval: 00:08
# Ep. 17, Timesteps 1600, Score.Agents: -123.83, Avg.Score: -280.98, Time: 00:03:45, Interval: 00:07
# Ep. 18, Timesteps 1600, Score.Agents: -116.33, Avg.Score: -272.31, Time: 00:03:52, Interval: 00:07
# Ep. 19, Timesteps 1600, Score.Agents: -112.30, Avg.Score: -264.31, Time: 00:04:01, Interval: 00:09
# Ep. 20, Timesteps 1600, Score.Agents: -99.68, Avg.Score: -256.47, Time: 00:04:10, Interval: 00:09
# Ep. 21, Timesteps 1600, Score.Agents: -96.77, Avg.Score: -249.21, Time: 00:04:20, Interval: 00:10
# Ep. 22, Timesteps 1600, Score.Agents: -83.52, Avg.Score: -242.01, Time: 00:04:29, Interval: 00:09
# Ep. 23, Timesteps 1600, Score.Agents: -102.39, Avg.Score: -236.19, Time: 00:04:38, Interval: 00:09
# Ep. 24, Timesteps 1600, Score.Agents: -86.60, Avg.Score: -230.21, Time: 00:04:47, Interval: 00:09
# Ep. 25, Timesteps 1600, Score.Agents: -91.69, Avg.Score: -224.88, Time: 00:04:56, Interval: 00:09
# Ep. 26, Timesteps 1600, Score.Agents: -78.71, Avg.Score: -219.47, Time: 00:05:06, Interval: 00:10
# Ep. 27, Timesteps 1600, Score.Agents: -77.10, Avg.Score: -214.38, Time: 00:05:15, Interval: 00:09
# Ep. 28, Timesteps 1600, Score.Agents: -71.89, Avg.Score: -209.47, Time: 00:05:24, Interval: 00:09
# Ep. 29, Timesteps 1600, Score.Agents: -78.15, Avg.Score: -205.09, Time: 00:05:32, Interval: 00:08
# Saving model, i_episode:  30
#
# Ep. 30, Timesteps 1600, Score.Agents: -86.83, Avg.Score: -201.28, Time: 00:05:41, Interval: 00:09
# Ep. 31, Timesteps 1600, Score.Agents: -73.53, Avg.Score: -197.29, Time: 00:05:50, Interval: 00:09
# Ep. 32, Timesteps 1600, Score.Agents: -51.44, Avg.Score: -192.87, Time: 00:05:59, Interval: 00:09
# Ep. 33, Timesteps 1600, Score.Agents: -40.17, Avg.Score: -188.38, Time: 00:06:07, Interval: 00:08
# Ep. 34, Timesteps 1600, Score.Agents: -40.16, Avg.Score: -184.14, Time: 00:06:16, Interval: 00:09
# Ep. 35, Timesteps 1600, Score.Agents: -26.47, Avg.Score: -179.76, Time: 00:06:24, Interval: 00:08
# Ep. 36, Timesteps 1600, Score.Agents: -57.08, Avg.Score: -176.44, Time: 00:06:33, Interval: 00:09
# Ep. 37, Timesteps 1600, Score.Agents: -22.65, Avg.Score: -172.40, Time: 00:06:41, Interval: 00:08
# Ep. 38, Timesteps 1600, Score.Agents: -14.69, Avg.Score: -168.35, Time: 00:06:50, Interval: 00:09
# Ep. 39, Timesteps 1600, Score.Agents: -12.90, Avg.Score: -164.47, Time: 00:06:58, Interval: 00:08
# Ep. 40, Timesteps 1600, Score.Agents: 3.62, Avg.Score: -160.37, Time: 00:07:06, Interval: 00:08
# Ep. 41, Timesteps 1600, Score.Agents: -9.79, Avg.Score: -156.78, Time: 00:07:15, Interval: 00:09
# Ep. 42, Timesteps 1600, Score.Agents: 1.95, Avg.Score: -153.09, Time: 00:07:23, Interval: 00:08
# Ep. 43, Timesteps 1600, Score.Agents: 22.65, Avg.Score: -149.10, Time: 00:07:32, Interval: 00:09
# Ep. 44, Timesteps 1600, Score.Agents: 6.34, Avg.Score: -145.64, Time: 00:07:40, Interval: 00:08
# Ep. 45, Timesteps 1600, Score.Agents: 27.56, Avg.Score: -141.88, Time: 00:07:49, Interval: 00:09
# Ep. 46, Timesteps 1600, Score.Agents: 30.25, Avg.Score: -138.21, Time: 00:07:58, Interval: 00:09
# Ep. 47, Timesteps 1600, Score.Agents: 33.80, Avg.Score: -134.63, Time: 00:08:06, Interval: 00:08
# Ep. 48, Timesteps 1600, Score.Agents: 39.21, Avg.Score: -131.08, Time: 00:08:13, Interval: 00:07
# Ep. 49, Timesteps 1600, Score.Agents: 51.14, Avg.Score: -127.44, Time: 00:08:20, Interval: 00:07
# Ep. 50, Timesteps 1600, Score.Agents: 48.74, Avg.Score: -123.98, Time: 00:08:27, Interval: 00:07
# Ep. 51, Timesteps 1600, Score.Agents: 55.07, Avg.Score: -120.54, Time: 00:08:35, Interval: 00:08
# Ep. 52, Timesteps 1600, Score.Agents: 76.28, Avg.Score: -116.83, Time: 00:08:42, Interval: 00:07
# Ep. 53, Timesteps 1600, Score.Agents: 42.88, Avg.Score: -113.87, Time: 00:08:49, Interval: 00:07
# Ep. 54, Timesteps 1600, Score.Agents: 62.94, Avg.Score: -110.66, Time: 00:08:56, Interval: 00:07
# Ep. 55, Timesteps 1600, Score.Agents: 86.99, Avg.Score: -107.13, Time: 00:09:03, Interval: 00:07
# Ep. 56, Timesteps 1600, Score.Agents: 102.00, Avg.Score: -103.46, Time: 00:09:10, Interval: 00:07
# Ep. 57, Timesteps 1600, Score.Agents: 82.69, Avg.Score: -100.25, Time: 00:09:18, Interval: 00:08
# Ep. 58, Timesteps 1600, Score.Agents: 84.85, Avg.Score: -97.11, Time: 00:09:25, Interval: 00:07
# Ep. 59, Timesteps 1600, Score.Agents: 87.94, Avg.Score: -94.03, Time: 00:09:32, Interval: 00:07
# Saving model, i_episode:  60
#
# Ep. 60, Timesteps 1600, Score.Agents: 112.57, Avg.Score: -90.64, Time: 00:09:39, Interval: 00:07
# Ep. 61, Timesteps 1600, Score.Agents: 106.81, Avg.Score: -87.45, Time: 00:09:47, Interval: 00:08
# Ep. 62, Timesteps 1600, Score.Agents: 121.97, Avg.Score: -84.13, Time: 00:09:54, Interval: 00:07
# Ep. 63, Timesteps 1600, Score.Agents: 126.54, Avg.Score: -80.84, Time: 00:10:02, Interval: 00:08
# Ep. 64, Timesteps 1600, Score.Agents: 122.12, Avg.Score: -77.72, Time: 00:10:09, Interval: 00:07
# Ep. 65, Timesteps 1600, Score.Agents: 133.01, Avg.Score: -74.52, Time: 00:10:16, Interval: 00:07
# Ep. 66, Timesteps 1600, Score.Agents: 117.82, Avg.Score: -71.65, Time: 00:10:23, Interval: 00:07
# Ep. 67, Timesteps 1600, Score.Agents: 125.10, Avg.Score: -68.76, Time: 00:10:31, Interval: 00:08
# Ep. 68, Timesteps 1600, Score.Agents: 119.63, Avg.Score: -66.03, Time: 00:10:38, Interval: 00:07
# Ep. 69, Timesteps 1600, Score.Agents: 119.21, Avg.Score: -63.38, Time: 00:10:45, Interval: 00:07
# Ep. 70, Timesteps 1600, Score.Agents: 129.55, Avg.Score: -60.67, Time: 00:10:52, Interval: 00:07
# Ep. 71, Timesteps 1600, Score.Agents: 126.95, Avg.Score: -58.06, Time: 00:10:59, Interval: 00:07
# Ep. 72, Timesteps 1600, Score.Agents: 139.19, Avg.Score: -55.36, Time: 00:11:06, Interval: 00:07
# Ep. 73, Timesteps 1600, Score.Agents: 120.44, Avg.Score: -52.98, Time: 00:11:14, Interval: 00:08
# Ep. 74, Timesteps 1600, Score.Agents: 136.24, Avg.Score: -50.46, Time: 00:11:21, Interval: 00:07
# Ep. 75, Timesteps 1600, Score.Agents: 137.15, Avg.Score: -47.99, Time: 00:11:28, Interval: 00:07
# Ep. 76, Timesteps 1600, Score.Agents: 148.46, Avg.Score: -45.44, Time: 00:11:35, Interval: 00:07
# Ep. 77, Timesteps 1600, Score.Agents: 140.41, Avg.Score: -43.06, Time: 00:11:42, Interval: 00:07
# Ep. 78, Timesteps 1600, Score.Agents: 132.81, Avg.Score: -40.83, Time: 00:11:50, Interval: 00:08
# Ep. 79, Timesteps 1600, Score.Agents: 150.32, Avg.Score: -38.44, Time: 00:11:57, Interval: 00:07
# Ep. 80, Timesteps 1600, Score.Agents: 131.12, Avg.Score: -36.35, Time: 00:12:04, Interval: 00:07
# Ep. 81, Timesteps 1600, Score.Agents: 135.30, Avg.Score: -34.25, Time: 00:12:11, Interval: 00:07
# Ep. 82, Timesteps 1600, Score.Agents: 159.33, Avg.Score: -31.92, Time: 00:12:18, Interval: 00:07
# Ep. 83, Timesteps 1600, Score.Agents: 154.02, Avg.Score: -29.71, Time: 00:12:25, Interval: 00:07
# Ep. 84, Timesteps 1600, Score.Agents: 148.49, Avg.Score: -27.61, Time: 00:12:33, Interval: 00:08
# Ep. 85, Timesteps 1600, Score.Agents: 142.43, Avg.Score: -25.63, Time: 00:12:40, Interval: 00:07
# Ep. 86, Timesteps 1600, Score.Agents: 166.49, Avg.Score: -23.43, Time: 00:12:47, Interval: 00:07
# Ep. 87, Timesteps 1600, Score.Agents: 154.96, Avg.Score: -21.40, Time: 00:12:55, Interval: 00:08
# Ep. 88, Timesteps 1600, Score.Agents: 159.90, Avg.Score: -19.36, Time: 00:13:02, Interval: 00:07
# Ep. 89, Timesteps 1600, Score.Agents: 164.82, Avg.Score: -17.32, Time: 00:13:09, Interval: 00:07
# Saving model, i_episode:  90
#
# Ep. 90, Timesteps 1600, Score.Agents: 152.26, Avg.Score: -15.45, Time: 00:13:16, Interval: 00:07
# Ep. 91, Timesteps 1600, Score.Agents: 169.68, Avg.Score: -13.44, Time: 00:13:24, Interval: 00:08
# Ep. 92, Timesteps 1600, Score.Agents: 177.17, Avg.Score: -11.39, Time: 00:13:32, Interval: 00:08
# Ep. 93, Timesteps 1600, Score.Agents: 163.13, Avg.Score: -9.53, Time: 00:13:40, Interval: 00:08
# Ep. 94, Timesteps 1600, Score.Agents: 170.39, Avg.Score: -7.64, Time: 00:13:47, Interval: 00:07
# Ep. 95, Timesteps 1600, Score.Agents: 147.36, Avg.Score: -6.03, Time: 00:13:54, Interval: 00:07
# Ep. 96, Timesteps 1600, Score.Agents: 168.86, Avg.Score: -4.22, Time: 00:14:01, Interval: 00:07
# Ep. 97, Timesteps 1600, Score.Agents: 144.60, Avg.Score: -2.70, Time: 00:14:08, Interval: 00:07
# Ep. 98, Timesteps 1600, Score.Agents: 170.34, Avg.Score: -0.96, Time: 00:14:15, Interval: 00:07
# Ep. 99, Timesteps 1600, Score.Agents: 173.91, Avg.Score: 0.79, Time: 00:14:22, Interval: 00:07
# Ep. 100, Timesteps 1600, Score.Agents: 178.79, Avg.Score: 12.11, Time: 00:14:29, Interval: 00:07
# Ep. 101, Timesteps 1600, Score.Agents: 154.95, Avg.Score: 22.62, Time: 00:14:37, Interval: 00:08
# Ep. 102, Timesteps 1600, Score.Agents: 174.25, Avg.Score: 29.21, Time: 00:14:44, Interval: 00:07
# Ep. 103, Timesteps 1600, Score.Agents: 139.64, Avg.Score: 34.29, Time: 00:14:51, Interval: 00:07
# Ep. 104, Timesteps 1600, Score.Agents: 166.55, Avg.Score: 38.74, Time: 00:14:58, Interval: 00:07
# Ep. 105, Timesteps 1600, Score.Agents: 180.87, Avg.Score: 43.25, Time: 00:15:05, Interval: 00:07
# Ep. 106, Timesteps 1600, Score.Agents: 189.11, Avg.Score: 46.83, Time: 00:15:12, Interval: 00:07
# Ep. 107, Timesteps 1600, Score.Agents: 145.02, Avg.Score: 50.15, Time: 00:15:19, Interval: 00:07
# Ep. 108, Timesteps 1600, Score.Agents: 171.69, Avg.Score: 53.66, Time: 00:15:26, Interval: 00:07
# Ep. 109, Timesteps 1600, Score.Agents: 170.86, Avg.Score: 57.41, Time: 00:15:34, Interval: 00:08
# Ep. 110, Timesteps 1600, Score.Agents: 173.12, Avg.Score: 60.32, Time: 00:15:41, Interval: 00:07
# Ep. 111, Timesteps 1600, Score.Agents: 191.38, Avg.Score: 63.68, Time: 00:15:48, Interval: 00:07
# Ep. 112, Timesteps 1600, Score.Agents: 183.77, Avg.Score: 66.77, Time: 00:15:55, Interval: 00:07
# Ep. 113, Timesteps 1600, Score.Agents: 199.26, Avg.Score: 70.54, Time: 00:16:02, Interval: 00:07
# Ep. 114, Timesteps 1600, Score.Agents: 183.82, Avg.Score: 73.95, Time: 00:16:09, Interval: 00:07
# Ep. 115, Timesteps 1600, Score.Agents: 191.38, Avg.Score: 77.04, Time: 00:16:16, Interval: 00:07
# Ep. 116, Timesteps 1600, Score.Agents: 201.76, Avg.Score: 80.09, Time: 00:16:23, Interval: 00:07
# Ep. 117, Timesteps 1600, Score.Agents: 207.19, Avg.Score: 83.40, Time: 00:16:30, Interval: 00:07
# Ep. 118, Timesteps 1600, Score.Agents: 210.44, Avg.Score: 86.67, Time: 00:16:38, Interval: 00:08
# Ep. 119, Timesteps 1600, Score.Agents: 208.95, Avg.Score: 89.88, Time: 00:16:45, Interval: 00:07
# Saving model, i_episode:  120
#
# Ep. 120, Timesteps 1600, Score.Agents: 200.45, Avg.Score: 92.89, Time: 00:16:52, Interval: 00:07
# Ep. 121, Timesteps 1600, Score.Agents: 175.12, Avg.Score: 95.60, Time: 00:17:00, Interval: 00:08
# Ep. 122, Timesteps 1600, Score.Agents: 212.14, Avg.Score: 98.56, Time: 00:17:07, Interval: 00:07
# Ep. 123, Timesteps 1600, Score.Agents: 204.18, Avg.Score: 101.63, Time: 00:17:14, Interval: 00:07
# Ep. 124, Timesteps 1600, Score.Agents: 218.46, Avg.Score: 104.68, Time: 00:17:21, Interval: 00:07
# Ep. 125, Timesteps 1600, Score.Agents: 226.22, Avg.Score: 107.86, Time: 00:17:28, Interval: 00:07
# Ep. 126, Timesteps 1600, Score.Agents: 228.43, Avg.Score: 110.93, Time: 00:17:36, Interval: 00:08
# Ep. 127, Timesteps 1600, Score.Agents: 223.43, Avg.Score: 113.93, Time: 00:17:43, Interval: 00:07
# Ep. 128, Timesteps 1600, Score.Agents: 207.10, Avg.Score: 116.72, Time: 00:17:50, Interval: 00:07
# Ep. 129, Timesteps 1600, Score.Agents: 196.30, Avg.Score: 119.47, Time: 00:17:57, Interval: 00:07
# Ep. 130, Timesteps 1600, Score.Agents: 205.03, Avg.Score: 122.39, Time: 00:18:04, Interval: 00:07
# Ep. 131, Timesteps 1600, Score.Agents: 239.91, Avg.Score: 125.52, Time: 00:18:11, Interval: 00:07
# Ep. 132, Timesteps 1600, Score.Agents: 229.06, Avg.Score: 128.33, Time: 00:18:18, Interval: 00:07
# Ep. 133, Timesteps 1600, Score.Agents: 240.26, Avg.Score: 131.13, Time: 00:18:25, Interval: 00:07
# Ep. 134, Timesteps 1600, Score.Agents: 239.33, Avg.Score: 133.92, Time: 00:18:33, Interval: 00:08
# Ep. 135, Timesteps 1600, Score.Agents: 255.17, Avg.Score: 136.74, Time: 00:18:40, Interval: 00:07
# Ep. 136, Timesteps 1600, Score.Agents: 245.87, Avg.Score: 139.77, Time: 00:18:47, Interval: 00:07
# Ep. 137, Timesteps 1600, Score.Agents: 212.07, Avg.Score: 142.12, Time: 00:18:54, Interval: 00:07
# Ep. 138, Timesteps 1600, Score.Agents: 227.34, Avg.Score: 144.54, Time: 00:19:01, Interval: 00:07
# Ep. 139, Timesteps 1600, Score.Agents: 259.13, Avg.Score: 147.26, Time: 00:19:08, Interval: 00:07
# Ep. 140, Timesteps 1600, Score.Agents: 254.38, Avg.Score: 149.77, Time: 00:19:15, Interval: 00:07
# Ep. 141, Timesteps 1600, Score.Agents: 246.96, Avg.Score: 152.33, Time: 00:19:22, Interval: 00:07
# Ep. 142, Timesteps 1600, Score.Agents: 239.31, Avg.Score: 154.71, Time: 00:19:30, Interval: 00:08
# Ep. 143, Timesteps 1600, Score.Agents: 240.04, Avg.Score: 156.88, Time: 00:19:37, Interval: 00:07
# Ep. 144, Timesteps 1600, Score.Agents: 249.56, Avg.Score: 159.31, Time: 00:19:44, Interval: 00:07
# Ep. 145, Timesteps 1600, Score.Agents: 236.74, Avg.Score: 161.40, Time: 00:19:51, Interval: 00:07
# Ep. 146, Timesteps 1600, Score.Agents: 227.12, Avg.Score: 163.37, Time: 00:19:58, Interval: 00:07
# Ep. 147, Timesteps 1600, Score.Agents: 232.22, Avg.Score: 165.36, Time: 00:20:05, Interval: 00:07
# Ep. 148, Timesteps 1600, Score.Agents: 242.47, Avg.Score: 167.39, Time: 00:20:13, Interval: 00:08
# Ep. 149, Timesteps 1600, Score.Agents: 236.81, Avg.Score: 169.25, Time: 00:20:20, Interval: 00:07
# Saving model, i_episode:  150
#
# Ep. 150, Timesteps 1600, Score.Agents: 244.74, Avg.Score: 171.21, Time: 00:20:27, Interval: 00:07
# Ep. 151, Timesteps 1600, Score.Agents: 240.46, Avg.Score: 173.06, Time: 00:20:35, Interval: 00:08
# Ep. 152, Timesteps 1600, Score.Agents: 230.91, Avg.Score: 174.61, Time: 00:20:42, Interval: 00:07
# Ep. 153, Timesteps 1600, Score.Agents: 247.40, Avg.Score: 176.65, Time: 00:20:50, Interval: 00:08
# Ep. 154, Timesteps 1600, Score.Agents: 196.43, Avg.Score: 177.99, Time: 00:20:57, Interval: 00:07
# Ep. 155, Timesteps 1600, Score.Agents: 230.60, Avg.Score: 179.42, Time: 00:21:04, Interval: 00:07
# Ep. 156, Timesteps 1600, Score.Agents: 253.79, Avg.Score: 180.94, Time: 00:21:11, Interval: 00:07
# Ep. 157, Timesteps 1600, Score.Agents: 266.61, Avg.Score: 182.78, Time: 00:21:18, Interval: 00:07
# Ep. 158, Timesteps 1600, Score.Agents: 250.97, Avg.Score: 184.44, Time: 00:21:25, Interval: 00:07
# Ep. 159, Timesteps 1600, Score.Agents: 240.57, Avg.Score: 185.97, Time: 00:21:32, Interval: 00:07
# Ep. 160, Timesteps 1600, Score.Agents: 252.89, Avg.Score: 187.37, Time: 00:21:40, Interval: 00:08
# Ep. 161, Timesteps 1600, Score.Agents: 253.69, Avg.Score: 188.84, Time: 00:21:47, Interval: 00:07
# Ep. 162, Timesteps 1600, Score.Agents: 270.85, Avg.Score: 190.33, Time: 00:21:54, Interval: 00:07
# Ep. 163, Timesteps 1600, Score.Agents: 226.45, Avg.Score: 191.33, Time: 00:22:01, Interval: 00:07
# Ep. 164, Timesteps 1600, Score.Agents: 252.61, Avg.Score: 192.63, Time: 00:22:08, Interval: 00:07
# Ep. 165, Timesteps 1600, Score.Agents: 251.71, Avg.Score: 193.82, Time: 00:22:15, Interval: 00:07
# Ep. 166, Timesteps 1600, Score.Agents: 237.46, Avg.Score: 195.02, Time: 00:22:22, Interval: 00:07
# Ep. 167, Timesteps 1600, Score.Agents: 210.12, Avg.Score: 195.87, Time: 00:22:29, Interval: 00:07
# Ep. 168, Timesteps 1600, Score.Agents: 256.52, Avg.Score: 197.23, Time: 00:22:36, Interval: 00:07
# Ep. 169, Timesteps 1600, Score.Agents: 227.45, Avg.Score: 198.32, Time: 00:22:44, Interval: 00:08
# Ep. 170, Timesteps 1600, Score.Agents: 228.96, Avg.Score: 199.31, Time: 00:22:51, Interval: 00:07
# Ep. 171, Timesteps 1600, Score.Agents: 227.55, Avg.Score: 200.32, Time: 00:22:58, Interval: 00:07
# Ep. 172, Timesteps 1600, Score.Agents: 237.93, Avg.Score: 201.30, Time: 00:23:05, Interval: 00:07
# Ep. 173, Timesteps 1600, Score.Agents: 246.35, Avg.Score: 202.56, Time: 00:23:12, Interval: 00:07
# Ep. 174, Timesteps 1600, Score.Agents: 253.11, Avg.Score: 203.73, Time: 00:23:19, Interval: 00:07
# Ep. 175, Timesteps 1600, Score.Agents: 250.78, Avg.Score: 204.87, Time: 00:23:27, Interval: 00:08
# Ep. 176, Timesteps 1600, Score.Agents: 266.01, Avg.Score: 206.04, Time: 00:23:34, Interval: 00:07
# Ep. 177, Timesteps 1600, Score.Agents: 261.89, Avg.Score: 207.26, Time: 00:23:41, Interval: 00:07
# Ep. 178, Timesteps 1600, Score.Agents: 249.36, Avg.Score: 208.42, Time: 00:23:48, Interval: 00:07
# Ep. 179, Timesteps 1600, Score.Agents: 267.03, Avg.Score: 209.59, Time: 00:23:55, Interval: 00:07
# Saving model, i_episode:  180
#
# Ep. 180, Timesteps 1600, Score.Agents: 253.09, Avg.Score: 210.81, Time: 00:24:02, Interval: 00:07
# Ep. 181, Timesteps 1600, Score.Agents: 239.32, Avg.Score: 211.85, Time: 00:24:10, Interval: 00:08
# Ep. 182, Timesteps 1600, Score.Agents: 260.08, Avg.Score: 212.86, Time: 00:24:18, Interval: 00:08
# Ep. 183, Timesteps 1600, Score.Agents: 254.51, Avg.Score: 213.86, Time: 00:24:25, Interval: 00:07
# Ep. 184, Timesteps 1600, Score.Agents: 260.09, Avg.Score: 214.98, Time: 00:24:32, Interval: 00:07
# Ep. 185, Timesteps 1600, Score.Agents: 240.06, Avg.Score: 215.96, Time: 00:24:39, Interval: 00:07
# Ep. 186, Timesteps 1600, Score.Agents: 244.88, Avg.Score: 216.74, Time: 00:24:47, Interval: 00:08
# Ep. 187, Timesteps 1600, Score.Agents: 252.92, Avg.Score: 217.72, Time: 00:24:54, Interval: 00:07
# Ep. 188, Timesteps 1600, Score.Agents: 259.76, Avg.Score: 218.72, Time: 00:25:01, Interval: 00:07
# Ep. 189, Timesteps 1600, Score.Agents: 247.30, Avg.Score: 219.54, Time: 00:25:08, Interval: 00:07
# Ep. 190, Timesteps 1600, Score.Agents: 251.08, Avg.Score: 220.53, Time: 00:25:15, Interval: 00:07
# Ep. 191, Timesteps 1600, Score.Agents: 272.77, Avg.Score: 221.56, Time: 00:25:22, Interval: 00:07
# Ep. 192, Timesteps 1600, Score.Agents: 246.30, Avg.Score: 222.25, Time: 00:25:29, Interval: 00:07
# Ep. 193, Timesteps 1600, Score.Agents: 259.26, Avg.Score: 223.21, Time: 00:25:36, Interval: 00:07
# Ep. 194, Timesteps 1600, Score.Agents: 254.39, Avg.Score: 224.05, Time: 00:25:44, Interval: 00:08
# Ep. 195, Timesteps 1600, Score.Agents: 233.85, Avg.Score: 224.92, Time: 00:25:51, Interval: 00:07
# Ep. 196, Timesteps 1600, Score.Agents: 255.68, Avg.Score: 225.79, Time: 00:25:58, Interval: 00:07
# Ep. 197, Timesteps 1600, Score.Agents: 254.92, Avg.Score: 226.89, Time: 00:26:05, Interval: 00:07
# Ep. 198, Timesteps 1600, Score.Agents: 241.97, Avg.Score: 227.61, Time: 00:26:12, Interval: 00:07
# Ep. 199, Timesteps 1600, Score.Agents: 259.13, Avg.Score: 228.46, Time: 00:26:19, Interval: 00:07
# Ep. 200, Timesteps 1600, Score.Agents: 272.19, Avg.Score: 229.39, Time: 00:26:27, Interval: 00:08
# Ep. 201, Timesteps 1600, Score.Agents: 264.11, Avg.Score: 230.48, Time: 00:26:34, Interval: 00:07
# Ep. 202, Timesteps 1600, Score.Agents: 247.58, Avg.Score: 231.22, Time: 00:26:41, Interval: 00:07
# Ep. 203, Timesteps 1600, Score.Agents: 247.89, Avg.Score: 232.30, Time: 00:26:48, Interval: 00:07
# Ep. 204, Timesteps 1600, Score.Agents: 246.67, Avg.Score: 233.10, Time: 00:26:55, Interval: 00:07
# Ep. 205, Timesteps 1600, Score.Agents: 267.88, Avg.Score: 233.97, Time: 00:27:03, Interval: 00:08
# Ep. 206, Timesteps 1600, Score.Agents: 262.29, Avg.Score: 234.70, Time: 00:27:10, Interval: 00:07
# Ep. 207, Timesteps 1600, Score.Agents: 258.94, Avg.Score: 235.84, Time: 00:27:17, Interval: 00:07
# Ep. 208, Timesteps 1600, Score.Agents: 268.96, Avg.Score: 236.82, Time: 00:27:24, Interval: 00:07
# Ep. 209, Timesteps 1600, Score.Agents: 260.26, Avg.Score: 237.71, Time: 00:27:31, Interval: 00:07
# Saving model, i_episode:  210
#
# Ep. 210, Timesteps 1600, Score.Agents: 265.95, Avg.Score: 238.64, Time: 00:27:38, Interval: 00:07
# Ep. 211, Timesteps 1600, Score.Agents: 269.90, Avg.Score: 239.42, Time: 00:27:46, Interval: 00:08
# Ep. 212, Timesteps 1600, Score.Agents: 257.93, Avg.Score: 240.16, Time: 00:27:54, Interval: 00:08
# Ep. 213, Timesteps 1600, Score.Agents: 266.42, Avg.Score: 240.84, Time: 00:28:01, Interval: 00:07
# Ep. 214, Timesteps 1600, Score.Agents: 282.10, Avg.Score: 241.82, Time: 00:28:08, Interval: 00:07
# Ep. 215, Timesteps 1600, Score.Agents: 281.96, Avg.Score: 242.72, Time: 00:28:15, Interval: 00:07
# Ep. 216, Timesteps 1600, Score.Agents: 245.60, Avg.Score: 243.16, Time: 00:28:23, Interval: 00:08
# Ep. 217, Timesteps 1600, Score.Agents: 242.83, Avg.Score: 243.52, Time: 00:28:30, Interval: 00:07
# Ep. 218, Timesteps 1600, Score.Agents: 272.09, Avg.Score: 244.14, Time: 00:28:37, Interval: 00:07
# Ep. 219, Timesteps 1600, Score.Agents: 266.57, Avg.Score: 244.71, Time: 00:28:44, Interval: 00:07
# Ep. 220, Timesteps 1600, Score.Agents: 279.30, Avg.Score: 245.50, Time: 00:28:52, Interval: 00:08
# Ep. 221, Timesteps 1600, Score.Agents: 268.54, Avg.Score: 246.44, Time: 00:28:59, Interval: 00:07
# Ep. 222, Timesteps 1600, Score.Agents: 278.54, Avg.Score: 247.10, Time: 00:29:06, Interval: 00:07
# Ep. 223, Timesteps 1600, Score.Agents: 258.79, Avg.Score: 247.65, Time: 00:29:13, Interval: 00:07
# Ep. 224, Timesteps 1600, Score.Agents: 278.30, Avg.Score: 248.24, Time: 00:29:20, Interval: 00:07
# Ep. 225, Timesteps 1600, Score.Agents: 275.13, Avg.Score: 248.73, Time: 00:29:27, Interval: 00:07
# Ep. 226, Timesteps 1600, Score.Agents: 255.26, Avg.Score: 249.00, Time: 00:29:35, Interval: 00:08
# Ep. 227, Timesteps 1600, Score.Agents: 260.12, Avg.Score: 249.37, Time: 00:29:42, Interval: 00:07
# Ep. 228, Timesteps 1600, Score.Agents: 277.65, Avg.Score: 250.07, Time: 00:29:49, Interval: 00:07
# Ep. 229, Timesteps 1600, Score.Agents: 264.84, Avg.Score: 250.76, Time: 00:29:56, Interval: 00:07
# Ep. 230, Timesteps 1600, Score.Agents: 269.31, Avg.Score: 251.40, Time: 00:30:03, Interval: 00:07
# Ep. 231, Timesteps 1600, Score.Agents: 274.34, Avg.Score: 251.75, Time: 00:30:11, Interval: 00:08
# Ep. 232, Timesteps 1600, Score.Agents: 284.09, Avg.Score: 252.30, Time: 00:30:18, Interval: 00:07
# Ep. 233, Timesteps 1600, Score.Agents: 279.50, Avg.Score: 252.69, Time: 00:30:25, Interval: 00:07
# Ep. 234, Timesteps 1600, Score.Agents: 268.73, Avg.Score: 252.98, Time: 00:30:32, Interval: 00:07
# Ep. 235, Timesteps 1600, Score.Agents: 270.26, Avg.Score: 253.13, Time: 00:30:39, Interval: 00:07
# Ep. 236, Timesteps 1600, Score.Agents: 262.43, Avg.Score: 253.30, Time: 00:30:46, Interval: 00:07
# Ep. 237, Timesteps 1600, Score.Agents: 262.06, Avg.Score: 253.80, Time: 00:30:53, Interval: 00:07
# Ep. 238, Timesteps 1600, Score.Agents: 286.22, Avg.Score: 254.39, Time: 00:31:00, Interval: 00:07
# Ep. 239, Timesteps 1600, Score.Agents: 295.15, Avg.Score: 254.75, Time: 00:31:07, Interval: 00:07
# Saving model, i_episode:  240
#
# Ep. 240, Timesteps 1600, Score.Agents: 265.71, Avg.Score: 254.86, Time: 00:31:15, Interval: 00:08
# Ep. 241, Timesteps 1600, Score.Agents: 285.77, Avg.Score: 255.25, Time: 00:31:22, Interval: 00:07
# Ep. 242, Timesteps 1600, Score.Agents: 287.14, Avg.Score: 255.73, Time: 00:31:30, Interval: 00:08
# Ep. 243, Timesteps 1600, Score.Agents: 286.15, Avg.Score: 256.19, Time: 00:31:37, Interval: 00:07
# Ep. 244, Timesteps 1600, Score.Agents: 274.42, Avg.Score: 256.44, Time: 00:31:44, Interval: 00:07
# Ep. 245, Timesteps 1600, Score.Agents: 282.11, Avg.Score: 256.89, Time: 00:31:52, Interval: 00:08
# Ep. 246, Timesteps 1600, Score.Agents: 288.82, Avg.Score: 257.51, Time: 00:31:59, Interval: 00:07
# Ep. 247, Timesteps 1600, Score.Agents: 284.40, Avg.Score: 258.03, Time: 00:32:06, Interval: 00:07
# Ep. 248, Timesteps 1600, Score.Agents: 286.28, Avg.Score: 258.47, Time: 00:32:13, Interval: 00:07
# Ep. 249, Timesteps 1600, Score.Agents: 287.04, Avg.Score: 258.97, Time: 00:32:20, Interval: 00:07
# Ep. 250, Timesteps 1600, Score.Agents: 288.79, Avg.Score: 259.41, Time: 00:32:27, Interval: 00:07
# Ep. 251, Timesteps 1600, Score.Agents: 303.76, Avg.Score: 260.04, Time: 00:32:35, Interval: 00:08
# Ep. 252, Timesteps 1600, Score.Agents: 294.72, Avg.Score: 260.68, Time: 00:32:42, Interval: 00:07
# Ep. 253, Timesteps 1600, Score.Agents: 284.07, Avg.Score: 261.05, Time: 00:32:49, Interval: 00:07
# Ep. 254, Timesteps 1600, Score.Agents: 277.90, Avg.Score: 261.86, Time: 00:32:56, Interval: 00:07
# Ep. 255, Timesteps 1600, Score.Agents: 289.14, Avg.Score: 262.45, Time: 00:33:03, Interval: 00:07
# Ep. 256, Timesteps 1600, Score.Agents: 295.88, Avg.Score: 262.87, Time: 00:33:10, Interval: 00:07
# Ep. 257, Timesteps 1600, Score.Agents: 286.51, Avg.Score: 263.07, Time: 00:33:17, Interval: 00:07
# Ep. 258, Timesteps 1600, Score.Agents: 271.65, Avg.Score: 263.28, Time: 00:33:24, Interval: 00:07
# Ep. 259, Timesteps 1600, Score.Agents: 288.81, Avg.Score: 263.76, Time: 00:33:31, Interval: 00:07
# Ep. 260, Timesteps 1600, Score.Agents: 295.34, Avg.Score: 264.18, Time: 00:33:38, Interval: 00:07
# Ep. 261, Timesteps 1600, Score.Agents: 280.81, Avg.Score: 264.45, Time: 00:33:45, Interval: 00:07
# Ep. 262, Timesteps 1600, Score.Agents: 287.51, Avg.Score: 264.62, Time: 00:33:53, Interval: 00:08
# Ep. 263, Timesteps 1600, Score.Agents: 291.31, Avg.Score: 265.27, Time: 00:34:00, Interval: 00:07
# Ep. 264, Timesteps 1600, Score.Agents: 268.34, Avg.Score: 265.43, Time: 00:34:07, Interval: 00:07
# Ep. 265, Timesteps 1600, Score.Agents: 294.65, Avg.Score: 265.86, Time: 00:34:14, Interval: 00:07
# Ep. 266, Timesteps 1600, Score.Agents: 263.07, Avg.Score: 266.11, Time: 00:34:21, Interval: 00:07
# Ep. 267, Timesteps 1600, Score.Agents: 265.62, Avg.Score: 266.67, Time: 00:34:28, Interval: 00:07
# Ep. 268, Timesteps 1600, Score.Agents: 280.37, Avg.Score: 266.91, Time: 00:34:36, Interval: 00:08
# Ep. 269, Timesteps 1600, Score.Agents: 243.50, Avg.Score: 267.07, Time: 00:34:43, Interval: 00:07
# Saving model, i_episode:  270
#
# Ep. 270, Timesteps 1600, Score.Agents: 272.77, Avg.Score: 267.50, Time: 00:34:50, Interval: 00:07
# Ep. 271, Timesteps 1600, Score.Agents: 289.84, Avg.Score: 268.13, Time: 00:34:58, Interval: 00:08
# Ep. 272, Timesteps 1600, Score.Agents: 269.75, Avg.Score: 268.44, Time: 00:35:06, Interval: 00:08
# Ep. 273, Timesteps 1600, Score.Agents: 251.13, Avg.Score: 268.49, Time: 00:35:13, Interval: 00:07
# Ep. 274, Timesteps 1600, Score.Agents: 265.68, Avg.Score: 268.62, Time: 00:35:20, Interval: 00:07
# Ep. 275, Timesteps 1600, Score.Agents: 289.06, Avg.Score: 269.00, Time: 00:35:27, Interval: 00:07
# Ep. 276, Timesteps 1600, Score.Agents: 308.41, Avg.Score: 269.43, Time: 00:35:34, Interval: 00:07
# Ep. 277, Timesteps 1600, Score.Agents: 300.70, Avg.Score: 269.81, Time: 00:35:41, Interval: 00:07
# Ep. 278, Timesteps 1600, Score.Agents: 298.43, Avg.Score: 270.30, Time: 00:35:48, Interval: 00:07
# Ep. 279, Timesteps 1600, Score.Agents: 270.71, Avg.Score: 270.34, Time: 00:35:55, Interval: 00:07
# Ep. 280, Timesteps 1600, Score.Agents: 294.48, Avg.Score: 270.75, Time: 00:36:03, Interval: 00:08
# Ep. 281, Timesteps 1600, Score.Agents: 296.49, Avg.Score: 271.33, Time: 00:36:10, Interval: 00:07
# Ep. 282, Timesteps 1600, Score.Agents: 286.40, Avg.Score: 271.59, Time: 00:36:17, Interval: 00:07
# Ep. 283, Timesteps 1600, Score.Agents: 286.87, Avg.Score: 271.91, Time: 00:36:24, Interval: 00:07
# Ep. 284, Timesteps 1600, Score.Agents: 285.09, Avg.Score: 272.16, Time: 00:36:31, Interval: 00:07
# Ep. 285, Timesteps 1600, Score.Agents: 281.05, Avg.Score: 272.57, Time: 00:36:38, Interval: 00:07
# Ep. 286, Timesteps 1600, Score.Agents: 290.37, Avg.Score: 273.03, Time: 00:36:46, Interval: 00:08
# Ep. 287, Timesteps 1600, Score.Agents: 291.69, Avg.Score: 273.42, Time: 00:36:53, Interval: 00:07
# Ep. 288, Timesteps 1600, Score.Agents: 282.97, Avg.Score: 273.65, Time: 00:37:00, Interval: 00:07
# Ep. 289, Timesteps 1600, Score.Agents: 286.81, Avg.Score: 274.04, Time: 00:37:07, Interval: 00:07
# Ep. 290, Timesteps 1600, Score.Agents: 257.50, Avg.Score: 274.11, Time: 00:37:14, Interval: 00:07
# Ep. 291, Timesteps 1600, Score.Agents: 277.25, Avg.Score: 274.15, Time: 00:37:21, Interval: 00:07
# Ep. 292, Timesteps 1600, Score.Agents: 288.46, Avg.Score: 274.57, Time: 00:37:28, Interval: 00:07
# Ep. 293, Timesteps 1600, Score.Agents: 271.73, Avg.Score: 274.70, Time: 00:37:35, Interval: 00:07
# Ep. 294, Timesteps 1600, Score.Agents: 304.95, Avg.Score: 275.20, Time: 00:37:43, Interval: 00:08
# Ep. 295, Timesteps 1600, Score.Agents: 289.95, Avg.Score: 275.77, Time: 00:37:50, Interval: 00:07
# Ep. 296, Timesteps 1600, Score.Agents: 300.50, Avg.Score: 276.21, Time: 00:37:57, Interval: 00:07
# Ep. 297, Timesteps 1600, Score.Agents: 258.47, Avg.Score: 276.25, Time: 00:38:04, Interval: 00:07
# Ep. 298, Timesteps 1600, Score.Agents: 275.45, Avg.Score: 276.58, Time: 00:38:11, Interval: 00:07
# Ep. 299, Timesteps 1600, Score.Agents: 278.32, Avg.Score: 276.78, Time: 00:38:18, Interval: 00:07
# Saving model, i_episode:  300
#
# Ep. 300, Timesteps 1600, Score.Agents: 290.05, Avg.Score: 276.95, Time: 00:38:25, Interval: 00:07
# Ep. 301, Timesteps 1600, Score.Agents: 295.90, Avg.Score: 277.27, Time: 00:38:33, Interval: 00:08
# Ep. 302, Timesteps 1600, Score.Agents: 280.56, Avg.Score: 277.60, Time: 00:38:41, Interval: 00:08
# Ep. 303, Timesteps 1600, Score.Agents: 278.29, Avg.Score: 277.91, Time: 00:38:48, Interval: 00:07
# Ep. 304, Timesteps 1600, Score.Agents: 286.50, Avg.Score: 278.30, Time: 00:38:55, Interval: 00:07
# Ep. 305, Timesteps 1600, Score.Agents: 305.14, Avg.Score: 278.68, Time: 00:39:03, Interval: 00:08
# Ep. 306, Timesteps 1600, Score.Agents: 277.29, Avg.Score: 278.83, Time: 00:39:10, Interval: 00:07
# Ep. 307, Timesteps 1600, Score.Agents: 304.85, Avg.Score: 279.29, Time: 00:39:17, Interval: 00:07
# Ep. 308, Timesteps 1600, Score.Agents: 274.48, Avg.Score: 279.34, Time: 00:39:24, Interval: 00:07
# Ep. 309, Timesteps 1600, Score.Agents: 296.80, Avg.Score: 279.71, Time: 00:39:31, Interval: 00:07
# Ep. 310, Timesteps 1600, Score.Agents: 295.84, Avg.Score: 280.01, Time: 00:39:38, Interval: 00:07
# Ep. 311, Timesteps 1600, Score.Agents: 295.45, Avg.Score: 280.26, Time: 00:39:45, Interval: 00:07
# Ep. 312, Timesteps 1600, Score.Agents: 278.26, Avg.Score: 280.46, Time: 00:39:52, Interval: 00:07
# Ep. 313, Timesteps 1600, Score.Agents: 299.93, Avg.Score: 280.80, Time: 00:39:59, Interval: 00:07
# Ep. 314, Timesteps 1600, Score.Agents: 275.38, Avg.Score: 280.73, Time: 00:40:07, Interval: 00:08
# Ep. 315, Timesteps 1600, Score.Agents: 290.41, Avg.Score: 280.82, Time: 00:40:14, Interval: 00:07
# Ep. 316, Timesteps 1600, Score.Agents: 300.07, Avg.Score: 281.36, Time: 00:40:21, Interval: 00:07
# Ep. 317, Timesteps 1600, Score.Agents: 283.31, Avg.Score: 281.77, Time: 00:40:28, Interval: 00:07
# Ep. 318, Timesteps 1600, Score.Agents: 300.25, Avg.Score: 282.05, Time: 00:40:36, Interval: 00:08
# Ep. 319, Timesteps 1600, Score.Agents: 298.76, Avg.Score: 282.37, Time: 00:40:43, Interval: 00:07
# Ep. 320, Timesteps 1600, Score.Agents: 286.85, Avg.Score: 282.45, Time: 00:40:50, Interval: 00:07
# Ep. 321, Timesteps 1600, Score.Agents: 302.58, Avg.Score: 282.79, Time: 00:40:57, Interval: 00:07
# Ep. 322, Timesteps 1600, Score.Agents: 305.99, Avg.Score: 283.06, Time: 00:41:04, Interval: 00:07
# Ep. 323, Timesteps 1600, Score.Agents: 288.15, Avg.Score: 283.35, Time: 00:41:12, Interval: 00:08
# Ep. 324, Timesteps 1600, Score.Agents: 295.26, Avg.Score: 283.52, Time: 00:41:19, Interval: 00:07
# Ep. 325, Timesteps 1600, Score.Agents: 311.18, Avg.Score: 283.88, Time: 00:41:26, Interval: 00:07
# Ep. 326, Timesteps 1600, Score.Agents: 296.33, Avg.Score: 284.29, Time: 00:41:33, Interval: 00:07
# Ep. 327, Timesteps 1600, Score.Agents: 311.76, Avg.Score: 284.81, Time: 00:41:40, Interval: 00:07
# Ep. 328, Timesteps 1600, Score.Agents: 308.48, Avg.Score: 285.12, Time: 00:41:47, Interval: 00:07
# Ep. 329, Timesteps 1600, Score.Agents: 294.91, Avg.Score: 285.42, Time: 00:41:54, Interval: 00:07
# Saving model, i_episode:  330
#
# Ep. 330, Timesteps 1600, Score.Agents: 290.37, Avg.Score: 285.63, Time: 00:42:02, Interval: 00:08
# Ep. 331, Timesteps 1600, Score.Agents: 289.97, Avg.Score: 285.79, Time: 00:42:09, Interval: 00:07
# Ep. 332, Timesteps 1600, Score.Agents: 305.43, Avg.Score: 286.00, Time: 00:42:17, Interval: 00:08
# Ep. 333, Timesteps 1600, Score.Agents: 300.52, Avg.Score: 286.21, Time: 00:42:24, Interval: 00:07
# Ep. 334, Timesteps 1600, Score.Agents: 300.73, Avg.Score: 286.53, Time: 00:42:31, Interval: 00:07
# Ep. 335, Timesteps 1600, Score.Agents: 298.87, Avg.Score: 286.82, Time: 00:42:39, Interval: 00:08
# Ep. 336, Timesteps 1600, Score.Agents: 310.33, Avg.Score: 287.30, Time: 00:42:46, Interval: 00:07
# Ep. 337, Timesteps 1600, Score.Agents: 312.89, Avg.Score: 287.80, Time: 00:42:53, Interval: 00:07
# Ep. 338, Timesteps 1600, Score.Agents: 312.86, Avg.Score: 288.07, Time: 00:43:00, Interval: 00:07
# Ep. 339, Timesteps 1600, Score.Agents: 304.57, Avg.Score: 288.16, Time: 00:43:07, Interval: 00:07
# Ep. 340, Timesteps 1600, Score.Agents: 325.59, Avg.Score: 288.76, Time: 00:43:14, Interval: 00:07
# Ep. 341, Timesteps 1600, Score.Agents: 290.89, Avg.Score: 288.81, Time: 00:43:21, Interval: 00:07
# Ep. 342, Timesteps 1600, Score.Agents: 287.32, Avg.Score: 288.82, Time: 00:43:28, Interval: 00:07
# Ep. 343, Timesteps 1600, Score.Agents: 321.42, Avg.Score: 289.17, Time: 00:43:35, Interval: 00:07
# Ep. 344, Timesteps 1600, Score.Agents: 318.54, Avg.Score: 289.61, Time: 00:43:43, Interval: 00:08
# Ep. 345, Timesteps 1600, Score.Agents: 308.29, Avg.Score: 289.87, Time: 00:43:50, Interval: 00:07
# Ep. 346, Timesteps 1600, Score.Agents: 306.03, Avg.Score: 290.04, Time: 00:43:57, Interval: 00:07
# Ep. 347, Timesteps 1600, Score.Agents: 300.94, Avg.Score: 290.21, Time: 00:44:04, Interval: 00:07
# Ep. 348, Timesteps 1600, Score.Agents: 314.51, Avg.Score: 290.49, Time: 00:44:12, Interval: 00:08
# Ep. 349, Timesteps 1600, Score.Agents: 302.97, Avg.Score: 290.65, Time: 00:44:19, Interval: 00:07
# Ep. 350, Timesteps 1600, Score.Agents: 327.13, Avg.Score: 291.03, Time: 00:44:26, Interval: 00:07
# Ep. 351, Timesteps 1600, Score.Agents: 324.24, Avg.Score: 291.24, Time: 00:44:33, Interval: 00:07
# Ep. 352, Timesteps 1600, Score.Agents: 312.68, Avg.Score: 291.42, Time: 00:44:40, Interval: 00:07
# Ep. 353, Timesteps 1600, Score.Agents: 308.73, Avg.Score: 291.67, Time: 00:44:47, Interval: 00:07
# Ep. 354, Timesteps 1600, Score.Agents: 321.63, Avg.Score: 292.10, Time: 00:44:54, Interval: 00:07
# Ep. 355, Timesteps 1600, Score.Agents: 301.97, Avg.Score: 292.23, Time: 00:45:01, Interval: 00:07
# Ep. 356, Timesteps 1600, Score.Agents: 303.52, Avg.Score: 292.31, Time: 00:45:09, Interval: 00:08
# Ep. 357, Timesteps 1600, Score.Agents: 302.99, Avg.Score: 292.47, Time: 00:45:16, Interval: 00:07
# Ep. 358, Timesteps 1600, Score.Agents: 304.33, Avg.Score: 292.80, Time: 00:45:23, Interval: 00:07
# Ep. 359, Timesteps 1600, Score.Agents: 309.30, Avg.Score: 293.00, Time: 00:45:30, Interval: 00:07
# Saving model, i_episode:  360
#
# Ep. 360, Timesteps 1600, Score.Agents: 282.76, Avg.Score: 292.88, Time: 00:45:37, Interval: 00:07
# Ep. 361, Timesteps 1600, Score.Agents: 299.90, Avg.Score: 293.07, Time: 00:45:45, Interval: 00:08
# Ep. 362, Timesteps 1600, Score.Agents: 321.05, Avg.Score: 293.40, Time: 00:45:52, Interval: 00:07
# Ep. 363, Timesteps 1600, Score.Agents: 303.42, Avg.Score: 293.53, Time: 00:46:00, Interval: 00:08
# Ep. 364, Timesteps 1600, Score.Agents: 284.62, Avg.Score: 293.69, Time: 00:46:07, Interval: 00:07
# Ep. 365, Timesteps 1600, Score.Agents: 318.19, Avg.Score: 293.92, Time: 00:46:14, Interval: 00:07
# Ep. 366, Timesteps 1600, Score.Agents: 321.69, Avg.Score: 294.51, Time: 00:46:21, Interval: 00:07
# Ep. 367, Timesteps 1600, Score.Agents: 317.94, Avg.Score: 295.03, Time: 00:46:28, Interval: 00:07
# Ep. 368, Timesteps 1600, Score.Agents: 315.89, Avg.Score: 295.39, Time: 00:46:35, Interval: 00:07
# Ep. 369, Timesteps 1600, Score.Agents: 316.97, Avg.Score: 296.12, Time: 00:46:43, Interval: 00:08
# Ep. 370, Timesteps 1600, Score.Agents: 303.65, Avg.Score: 296.43, Time: 00:46:50, Interval: 00:07
# Ep. 371, Timesteps 1600, Score.Agents: 318.13, Avg.Score: 296.71, Time: 00:46:57, Interval: 00:07
# Ep. 372, Timesteps 1600, Score.Agents: 334.70, Avg.Score: 297.36, Time: 00:47:04, Interval: 00:07
# Ep. 373, Timesteps 1600, Score.Agents: 297.06, Avg.Score: 297.82, Time: 00:47:11, Interval: 00:07
# Ep. 374, Timesteps 1600, Score.Agents: 302.67, Avg.Score: 298.19, Time: 00:47:18, Interval: 00:07
# Ep. 375, Timesteps 1600, Score.Agents: 297.08, Avg.Score: 298.27, Time: 00:47:25, Interval: 00:07
# Ep. 376, Timesteps 1600, Score.Agents: 305.52, Avg.Score: 298.24, Time: 00:47:33, Interval: 00:08
# Ep. 377, Timesteps 1600, Score.Agents: 308.49, Avg.Score: 298.32, Time: 00:47:40, Interval: 00:07
# Ep. 378, Timesteps 1600, Score.Agents: 330.57, Avg.Score: 298.64, Time: 00:47:47, Interval: 00:07
# Ep. 379, Timesteps 1600, Score.Agents: 322.13, Avg.Score: 299.16, Time: 00:47:54, Interval: 00:07
# Ep. 380, Timesteps 1600, Score.Agents: 296.51, Avg.Score: 299.18, Time: 00:48:01, Interval: 00:07
# Ep. 381, Timesteps 1600, Score.Agents: 308.29, Avg.Score: 299.30, Time: 00:48:09, Interval: 00:08
# Ep. 382, Timesteps 1600, Score.Agents: 307.63, Avg.Score: 299.51, Time: 00:48:16, Interval: 00:07
# Ep. 383, Timesteps 1600, Score.Agents: 322.29, Avg.Score: 299.86, Time: 00:48:23, Interval: 00:07
# Ep. 384, Timesteps 1600, Score.Agents: 327.97, Avg.Score: 300.29, Time: 00:48:30, Interval: 00:07
# Ep. 385, Timesteps 1600, Score.Agents: 329.66, Avg.Score: 300.78, Time: 00:48:37, Interval: 00:07
# Environment solved with Average Score:  300.7779706447256

# %%
save(model=policy,directory='dir_save',filename='we0',suffix='final')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

print('length of scores: ', len(scores), ', len of avg_scores: ', len(avg_scores))

fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores, label="Score")
plt.plot(np.arange(1, len(avg_scores)+1), avg_scores, label="Avg on 100 episodes")
plt.legend(bbox_to_anchor=(1.05, 1)) 
plt.ylabel('Score')
plt.xlabel('Episodes #')
plt.show()
# Out:
# length of scores:  386 , len of avg_scores:  386

# %%
import pandas as pd

# Export 1D array to CSV (values along columns)
df_1d = pd.DataFrame(scores)
df_1d.to_csv('PPO.csv', index=False, header=False)

# %%
#--------------- make_vec_envs ----------------
## we continue with the same model, model Policy uses MLPBase, but with new environment env_venv

device = torch.device("cpu")
print('device: ', device)

seed = 0 
num_processes=1  

env_venv = make_vec_envs('BipedalWalker-v3', \
                    seed + 1000, num_processes,
                    None, None, False, device='cpu', allow_early_resets=False)

policy = policy.to(device)

print('env_venv.observation_space.shape: ', env_venv.observation_space.shape, \
      ', len(obs_shape): ', len(env_venv.observation_space.shape))
print('env_venv.action_space: ',  env_venv.action_space, \
      ', action_space.shape[0]: ', env_venv.action_space.shape[0])
# Out:
# device:  cpu
# env_venv.observation_space.shape:  (24,) , len(obs_shape):  1
# env_venv.action_space:  Box([-1. -1. -1. -1.], [1. 1. 1. 1.], (4,), float32) , action_space.shape[0]:  4

# %%
## No CUDA, only CPU

def play_VecEnv(env, model, num_episodes):

    obs = env.reset()
    obs = torch.Tensor(obs)
    obs = obs.float()
        
    recurrent_hidden_states = torch.zeros(1, model.recurrent_hidden_state_size)
    
    masks = torch.zeros(1, 1)
    
    scores_deque = deque(maxlen=100)

    render_func = get_render_func(env)
        
    for i_episode in range(1, num_episodes+1):     

        time_start = time.time()
        total_reward = np.zeros(num_processes)
        timestep = 0

        while True:
        
            with torch.no_grad():
                value, action, _, recurrent_hidden_states = \
                    model.act(obs, recurrent_hidden_states, masks, \
                    deterministic=False) # obs = state

            render_func()
            
            obs, reward, done, _ = env.step(action)
            obs = torch.Tensor(obs)
            obs = obs.float()

            reward = reward.detach().numpy()
            
            masks.fill_(0.0 if done else 1.0)
            
            total_reward += reward[0]
        
            #if timestep < 800:
            #    print('timestep: ', timestep, 'reward: ', reward[0])
            
            timestep += 1
            
            if timestep + 1 == 1600: ##   envs.max_steps:
                break

        s = (int)(time.time() - time_start)
        
        scores_deque.append(total_reward[0])
        
        avg_score = np.mean(scores_deque)
                    
        print('Episode {} \tScore: {:.2f}, Avg.Score: {:.2f}, \tTime: {:02}:{:02}:{:02}'\
                  .format(i_episode, total_reward[0], avg_score,  s//3600, s%3600//60, s%60))

# %%
play_VecEnv(env=env_venv, model=policy, num_episodes=1)
# Out:
# Episode 1 	Score: 331.62, Avg.Score: 331.62, 	Time: 00:00:55

# %%
env_venv.close()
obs = env_venv.reset()
# obs.close() # Remove this line as it causes the AttributeError
env_venv.close()
