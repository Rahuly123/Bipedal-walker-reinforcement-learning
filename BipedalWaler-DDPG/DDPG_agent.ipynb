# %%
# !pip install wheel setuptools pip --upgrade

# %%
# !pip install gymnasium
# !pip install swig
# !pip install gymnasium[box2d]

# %%
import tensorflow as tf
from tensorflow import keras
import gym as gym
from gym.spaces import Box
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from time import perf_counter
from datetime import timedelta

# %%
import ddpg
import memory
import models
import utils

# %%
env = gym.make('BipedalWalker-v3')
params = {
    'env_name' : 'BipedalWalker-v3',
    'n_runs': 1,
    'n_actions': env.action_space.shape[0],
    'action_bounds': [env.action_space.low, env.action_space.high],
    'obs_shape': (1, *env.observation_space.shape),
    'n_steps': 500_000,  # env steps
    'evaluation_frequency': 100,  # evaluate agent every that many episodes
    'actor_lr': 0.0003,
    'critic_lr': 0.0004,
    'gamma': 0.99,
    'tau': 0.001,
    'minibatch': 64,
    'buffer_size': 1_000_000,
    'n_neurons': [128, 128],  # number of neurons for each of the hidden layers
    'learning_starts': 10_000,  # play randomly for that many steps
    'random_process_parameters': [0, 0.1],  # [mean, stddev]
    'seed' : 2023
}

# %%
all_episode_returns = []
all_episode_lengths = []
all_critic_losses = []

# %%
for i in range(params['n_runs']):
  # utils.set_seed(params['seed']+i)
  agent = models.Agent(params)
  target_agent = models.Agent(params)
  s = np.array([env.observation_space.sample()])
  a, at = agent.actor.call(s), target_agent.actor.call(s)
  q, qt = agent.critic.call([s, a]), target_agent.critic.call([s, at])
  start_time = perf_counter()
  episode_returns, episode_lengths, critic_losses = ddpg.train(agent=agent, target_agent=target_agent, params=params)
  end_time = perf_counter()

  print(f"\nRun:{i} Training time: _ _ _ _ _{str(timedelta(seconds=end_time - start_time))}_ _ _ _ _")

  all_episode_lengths.append(episode_lengths)
  all_episode_returns.append(episode_returns)
  all_critic_losses.append(critic_losses)
# Out:
# step:78         episode:1       return:-122    length:77
# step:1678       episode:2       return:-89     length:1600
# step:1740       episode:3       return:-101    length:62
# step:3340       episode:4       return:-79     length:1600
# step:4940       episode:5       return:-83     length:1600
# step:5001       episode:6       return:-114    length:61
# step:5064       episode:7       return:-110    length:63
# step:6664       episode:8       return:-84     length:1600
# step:8264       episode:9       return:-89     length:1600
# step:8352       episode:10      return:-99     length:88
# step:9952       episode:11      return:-87     length:1600
# WARNING:tensorflow:5 out of the last 5 calls to <function Agent._update_weights at 0x0000027ABBFE16A8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function Agent._update_weights at 0x0000027ABBFE16A8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# step:10086      episode:12      return:-111    length:134
# step:10217      episode:13      return:-115    length:131
# step:10255      episode:14      return:-119    length:38
# step:10348      episode:15      return:-114    length:93
# step:10503      episode:16      return:-115    length:155
# step:10573      episode:17      return:-111    length:70
# step:10777      episode:18      return:-137    length:204
# step:10855      episode:19      return:-120    length:78
# step:10939      episode:20      return:-116    length:84
# step:11040      episode:21      return:-117    length:101
# step:12640      episode:22      return:-112    length:1600
# step:12692      episode:23      return:-108    length:52
# step:12787      episode:24      return:-120    length:95
# step:12847      episode:25      return:-119    length:60
# step:12947      episode:26      return:-111    length:100
# step:13930      episode:27      return:-191    length:983
# step:14005      episode:28      return:-113    length:75
# step:14139      episode:29      return:-127    length:134
# step:14223      episode:30      return:-125    length:84
# step:14302      episode:31      return:-118    length:79
# step:14372      episode:32      return:-116    length:70
# step:14432      episode:33      return:-106    length:60
# step:14502      episode:34      return:-114    length:70
# step:14570      episode:35      return:-109    length:68
# step:14642      episode:36      return:-119    length:72
# step:14715      episode:37      return:-113    length:73
# step:14806      episode:38      return:-110    length:91
# step:14896      episode:39      return:-109    length:90
# step:14970      episode:40      return:-119    length:74
# step:15048      episode:41      return:-114    length:78
# step:15147      episode:42      return:-122    length:99
# step:15228      episode:43      return:-122    length:81
# step:15316      episode:44      return:-122    length:88
# step:15399      episode:45      return:-120    length:83
# step:15487      episode:46      return:-120    length:88
# step:15568      episode:47      return:-111    length:81
# step:15721      episode:48      return:-134    length:153
# step:15894      episode:49      return:-124    length:173
# step:15973      episode:50      return:-106    length:79
# step:16237      episode:51      return:-131    length:264
# step:16302      episode:52      return:-118    length:65
# step:16383      episode:53      return:-121    length:81
# step:16471      episode:54      return:-121    length:88
# step:16669      episode:55      return:-129    length:198
# step:16758      episode:56      return:-121    length:89
# step:16839      episode:57      return:-107    length:81
# step:16910      episode:58      return:-118    length:71
# step:16952      episode:59      return:-118    length:42
# step:17030      episode:60      return:-107    length:78
# step:17126      episode:61      return:-109    length:96
# step:17243      episode:62      return:-111    length:117
# step:17329      episode:63      return:-109    length:86
# step:17412      episode:64      return:-118    length:83
# step:17470      episode:65      return:-115    length:58
# step:17534      episode:66      return:-112    length:64
# step:17650      episode:67      return:-111    length:116
# step:17774      episode:68      return:-120    length:124
# step:17820      episode:69      return:-116    length:46
# step:17882      episode:70      return:-116    length:62
# step:17943      episode:71      return:-109    length:61
# step:18000      episode:72      return:-116    length:57
# step:18060      episode:73      return:-110    length:60
# step:18135      episode:74      return:-122    length:75
# step:18183      episode:75      return:-117    length:48
# step:18226      episode:76      return:-116    length:43
# step:18349      episode:77      return:-106    length:123
# step:18386      episode:78      return:-115    length:37
# step:19791      episode:79      return:-188    length:1405
# step:19826      episode:80      return:-111    length:35
# step:19882      episode:81      return:-107    length:56
# step:19939      episode:82      return:-106    length:57
# step:20019      episode:83      return:-121    length:80
# step:20129      episode:84      return:-127    length:110
# step:20167      episode:85      return:-117    length:38
# step:20206      episode:86      return:-116    length:39
# step:21806      episode:87      return:-112    length:1600
# step:21879      episode:88      return:-118    length:73
# step:21993      episode:89      return:-131    length:114
# step:22108      episode:90      return:-135    length:115
# step:22185      episode:91      return:-120    length:77
# step:22250      episode:92      return:-123    length:65
# step:23807      episode:93      return:-193    length:1557
# step:23857      episode:94      return:-119    length:50
# step:23940      episode:95      return:-124    length:83
# step:24035      episode:96      return:-102    length:95
# step:24106      episode:97      return:-123    length:71
# step:24245      episode:98      return:-106    length:139
# step:24296      episode:99      return:-118    length:51
# step:24386      episode:100     return:-125    length:90
# step:24470      episode:101     return:-123    length:84
# step:24564      episode:102     return:-126    length:94
# step:24615      episode:103     return:-118    length:51
# step:24711      episode:104     return:-127    length:96
# step:24810      episode:105     return:-125    length:99
# step:25062      episode:106     return:-114    length:252
# step:25160      episode:107     return:-130    length:98
# step:25253      episode:108     return:-125    length:93
# step:25306      episode:109     return:-118    length:53
# step:25389      episode:110     return:-100    length:83
# step:25456      episode:111     return:-121    length:67
# step:25607      episode:112     return:-124    length:151
# step:25714      episode:113     return:-100    length:107
# step:25791      episode:114     return:-120    length:77
# step:25841      episode:115     return:-107    length:50
# step:26001      episode:116     return:-121    length:160
# step:26137      episode:117     return:-106    length:136
# step:26295      episode:118     return:-134    length:158
# step:26381      episode:119     return:-101    length:86
# step:26437      episode:120     return:-117    length:56
# step:26539      episode:121     return:-102    length:102
# step:26596      episode:122     return:-101    length:57
# step:26652      episode:123     return:-101    length:56
# step:26705      episode:124     return:-101    length:53
# step:26758      episode:125     return:-102    length:53
# step:28358      episode:126     return:-106    length:1600
# step:28411      episode:127     return:-105    length:53
# step:28473      episode:128     return:-104    length:62
# step:28533      episode:129     return:-105    length:60
# step:28591      episode:130     return:-103    length:58
# step:28658      episode:131     return:-105    length:67
# step:28730      episode:132     return:-105    length:72
# step:28790      episode:133     return:-105    length:60
# step:28861      episode:134     return:-103    length:71
# step:28932      episode:135     return:-105    length:71
# step:28979      episode:136     return:-106    length:47
# step:29043      episode:137     return:-103    length:64
# step:29089      episode:138     return:-108    length:46
# step:29135      episode:139     return:-106    length:46
# step:29217      episode:140     return:-102    length:82
# step:29292      episode:141     return:-104    length:75
# step:29350      episode:142     return:-105    length:58
# step:29406      episode:143     return:-105    length:56
# step:29478      episode:144     return:-105    length:72
# step:29533      episode:145     return:-105    length:55
# step:29616      episode:146     return:-103    length:83
# step:29665      episode:147     return:-109    length:49
# step:29727      episode:148     return:-102    length:62
# step:29809      episode:149     return:-105    length:82
# step:29894      episode:150     return:-103    length:85
# step:29944      episode:151     return:-106    length:50
# step:29995      episode:152     return:-107    length:51
# step:30053      episode:153     return:-102    length:58
# step:31115      episode:154     return:-189    length:1062
# step:31401      episode:155     return:-137    length:286
# step:31674      episode:156     return:-136    length:273
# step:32070      episode:157     return:-120    length:396
# step:32130      episode:158     return:-102    length:60
# step:32180      episode:159     return:-106    length:50
# step:32451      episode:160     return:-129    length:271
# step:32505      episode:161     return:-104    length:54
# step:32548      episode:162     return:-108    length:43
# step:32591      episode:163     return:-109    length:43
# step:32631      episode:164     return:-107    length:40
# step:32686      episode:165     return:-102    length:55
# step:32767      episode:166     return:-103    length:81
# step:32876      episode:167     return:-103    length:109
# step:32953      episode:168     return:-103    length:77
# step:33086      episode:169     return:-105    length:133
# step:33138      episode:170     return:-105    length:52
# step:33197      episode:171     return:-104    length:59
# step:33241      episode:172     return:-107    length:44
# step:33285      episode:173     return:-108    length:44
# step:33396      episode:174     return:-101    length:111
# step:33470      episode:175     return:-104    length:74
# step:33543      episode:176     return:-103    length:73
# step:33648      episode:177     return:-99     length:105
# step:33760      episode:178     return:-103    length:112
# step:33833      episode:179     return:-104    length:73
# step:33907      episode:180     return:-121    length:74
# step:33948      episode:181     return:-107    length:41
# step:34063      episode:182     return:-102    length:115
# step:34146      episode:183     return:-117    length:83
# step:34195      episode:184     return:-105    length:49
# step:34236      episode:185     return:-106    length:41
# step:34276      episode:186     return:-116    length:40
# step:34392      episode:187     return:-105    length:116
# step:34466      episode:188     return:-104    length:74
# step:34551      episode:189     return:-128    length:85
# step:34678      episode:190     return:-103    length:127
# step:34778      episode:191     return:-129    length:100
# step:34854      episode:192     return:-101    length:76
# step:34960      episode:193     return:-105    length:106
# step:35037      episode:194     return:-104    length:77
# step:35144      episode:195     return:-130    length:107
# step:35232      episode:196     return:-101    length:88
# step:35331      episode:197     return:-134    length:99
# step:35415      episode:198     return:-103    length:84
# step:35514      episode:199     return:-133    length:99
# step:35714      episode:200     return:-145    length:200
# step:35817      episode:201     return:-126    length:103
# step:35896      episode:202     return:-125    length:79
# step:35979      episode:203     return:-103    length:83
# step:36031      episode:204     return:-105    length:52
# step:36080      episode:205     return:-104    length:49
# step:36136      episode:206     return:-105    length:56
# step:36194      episode:207     return:-103    length:58
# step:36347      episode:208     return:-139    length:153
# step:36453      episode:209     return:-132    length:106
# step:38053      episode:210     return:-115    length:1600
# step:38582      episode:211     return:-156    length:529
# step:38960      episode:212     return:-137    length:378
# step:39464      episode:213     return:-146    length:504
# step:39675      episode:214     return:-122    length:211
# step:39888      episode:215     return:-126    length:213
# step:40091      episode:216     return:-122    length:203
# step:40187      episode:217     return:-122    length:96
# step:40390      episode:218     return:-127    length:203
# step:40582      episode:219     return:-124    length:192
# step:40725      episode:220     return:-132    length:143
# step:41012      episode:221     return:-130    length:287
# step:41196      episode:222     return:-121    length:184
# step:41499      episode:223     return:-128    length:303
# step:41645      episode:224     return:-117    length:146
# step:41962      episode:225     return:-134    length:317
# step:42143      episode:226     return:-119    length:181
# step:42454      episode:227     return:-142    length:311
# step:42668      episode:228     return:-126    length:214
# step:44268      episode:229     return:-105    length:1600
# step:45755      episode:230     return:-226    length:1487
# step:47355      episode:231     return:-128    length:1600
# step:48252      episode:232     return:-189    length:897
# step:49852      episode:233     return:-119    length:1600
# step:49910      episode:234     return:-110    length:58
# step:51510      episode:235     return:-131    length:1600
# step:51580      episode:236     return:-103    length:70
# step:53180      episode:237     return:-130    length:1600
# step:54780      episode:238     return:-156    length:1600
# step:56380      episode:239     return:-115    length:1600
# step:57980      episode:240     return:-136    length:1600
# step:59580      episode:241     return:-141    length:1600
# step:61180      episode:242     return:-126    length:1600
# step:62780      episode:243     return:-123    length:1600
# step:64380      episode:244     return:-105    length:1600
# step:65980      episode:245     return:-97     length:1600
# step:67580      episode:246     return:-120    length:1600
# step:67735      episode:247     return:-142    length:155
# step:69335      episode:248     return:-111    length:1600
# step:70935      episode:249     return:-121    length:1600
# step:71002      episode:250     return:-110    length:67
# step:72602      episode:251     return:-114    length:1600
# step:72724      episode:252     return:-113    length:122
# step:72881      episode:253     return:-114    length:157
# step:73050      episode:254     return:-117    length:169
# step:73218      episode:255     return:-116    length:168
# step:73354      episode:256     return:-109    length:136
# step:73469      episode:257     return:-109    length:115
# step:73580      episode:258     return:-112    length:111
# step:73693      episode:259     return:-111    length:113
# step:73797      episode:260     return:-113    length:104
# step:73913      episode:261     return:-111    length:116
# step:74023      episode:262     return:-109    length:110
# step:74164      episode:263     return:-111    length:141
# step:74372      episode:264     return:-118    length:208
# step:74464      episode:265     return:-114    length:92
# step:74608      episode:266     return:-111    length:144
# step:74724      episode:267     return:-110    length:116
# step:74835      episode:268     return:-111    length:111
# step:75005      episode:269     return:-112    length:170
# step:75128      episode:270     return:-110    length:123
# step:75228      episode:271     return:-109    length:100
# step:75321      episode:272     return:-109    length:93
# step:75444      episode:273     return:-109    length:123
# step:75496      episode:274     return:-110    length:52
# step:75616      episode:275     return:-110    length:120
# step:75673      episode:276     return:-109    length:57
# step:75804      episode:277     return:-114    length:131
# step:75933      episode:278     return:-111    length:129
# step:75982      episode:279     return:-109    length:49
# step:76081      episode:280     return:-106    length:99
# step:76217      episode:281     return:-111    length:136
# step:76266      episode:282     return:-107    length:49
# step:76318      episode:283     return:-109    length:52
# step:76377      episode:284     return:-105    length:59
# step:76437      episode:285     return:-108    length:60
# step:76498      episode:286     return:-106    length:61
# step:76554      episode:287     return:-106    length:56
# step:76946      episode:288     return:-132    length:392
# step:77095      episode:289     return:-110    length:149
# step:78695      episode:290     return:-132    length:1600
# step:79723      episode:291     return:-176    length:1028
# step:80033      episode:292     return:-122    length:310
# step:80190      episode:293     return:-112    length:157
# step:80461      episode:294     return:-119    length:271
# step:80605      episode:295     return:-108    length:144
# step:81086      episode:296     return:-132    length:481
# step:81214      episode:297     return:-105    length:128
# step:81322      episode:298     return:-107    length:108
# step:81511      episode:299     return:-110    length:189
# step:81682      episode:300     return:-109    length:171
# step:82283      episode:301     return:-151    length:601
# step:82409      episode:302     return:-106    length:126
# step:82545      episode:303     return:-113    length:136
# step:83136      episode:304     return:-141    length:591
# step:83274      episode:305     return:-106    length:138
# step:83431      episode:306     return:-108    length:157
# step:83542      episode:307     return:-106    length:111
# step:83660      episode:308     return:-99     length:118
# step:83841      episode:309     return:-110    length:181
# step:83941      episode:310     return:-97     length:100
# step:84211      episode:311     return:-115    length:270
# step:84322      episode:312     return:-111    length:111
# step:84463      episode:313     return:-109    length:141
# step:84616      episode:314     return:-111    length:153
# step:84878      episode:315     return:-116    length:262
# step:85019      episode:316     return:-107    length:141
# step:85471      episode:317     return:-142    length:452
# step:85624      episode:318     return:-110    length:153
# step:86187      episode:319     return:-141    length:563
# step:86483      episode:320     return:-127    length:296
# step:86737      episode:321     return:-120    length:254
# step:87034      episode:322     return:-120    length:297
# step:87361      episode:323     return:-124    length:327
# step:87733      episode:324     return:-133    length:372
# step:88052      episode:325     return:-126    length:319
# step:88360      episode:326     return:-113    length:308
# step:88939      episode:327     return:-157    length:579
# step:89217      episode:328     return:-116    length:278
# step:89391      episode:329     return:-104    length:174
# step:89861      episode:330     return:-140    length:470
# step:90143      episode:331     return:-113    length:282
# step:90354      episode:332     return:-115    length:211
# step:90581      episode:333     return:-108    length:227
# step:90905      episode:334     return:-116    length:324
# step:91126      episode:335     return:-100    length:221
# step:91232      episode:336     return:-102    length:106
# step:91471      episode:337     return:-102    length:239
# step:91802      episode:338     return:-131    length:331
# step:93402      episode:339     return:-43     length:1600
# step:95002      episode:340     return:-73     length:1600
# step:96602      episode:341     return:-105    length:1600
# step:98202      episode:342     return:-110    length:1600
# step:98694      episode:343     return:-151    length:492
# step:98903      episode:344     return:-135    length:209
# step:100427     episode:345     return:-225    length:1524
# step:101046     episode:346     return:-167    length:619
# step:102646     episode:347     return:-116    length:1600
# step:104246     episode:348     return:-116    length:1600
# step:105846     episode:349     return:-111    length:1600
# step:107446     episode:350     return:-112    length:1600
# step:109046     episode:351     return:-109    length:1600
# step:110646     episode:352     return:-114    length:1600
# step:112246     episode:353     return:-109    length:1600
# step:113846     episode:354     return:-60     length:1600
# step:115446     episode:355     return:-89     length:1600
# step:117046     episode:356     return:-86     length:1600
# step:118646     episode:357     return:-85     length:1600
# step:120246     episode:358     return:-105    length:1600
# step:121846     episode:359     return:-100    length:1600
# step:123446     episode:360     return:-96     length:1600
# step:125046     episode:361     return:-53     length:1600
# step:125133     episode:362     return:-126    length:87
# step:125188     episode:363     return:-120    length:55
# step:126788     episode:364     return:-33     length:1600
# step:126916     episode:365     return:-127    length:128
# step:128516     episode:366     return:-33     length:1600
# step:130116     episode:367     return:-16     length:1600
# step:130206     episode:368     return:-112    length:90
# step:130314     episode:369     return:-132    length:108
# step:131914     episode:370     return:-5      length:1600
# step:133514     episode:371     return:-3      length:1600
# step:135114     episode:372     return:-14     length:1600
# step:136714     episode:373     return:-56     length:1600
# step:138314     episode:374     return:-14     length:1600
# step:139914     episode:375     return:30      length:1600
# step:140137     episode:376     return:-129    length:223
# step:141323     episode:377     return:-86     length:1186
# step:142152     episode:378     return:-90     length:829
# step:142772     episode:379     return:-109    length:620
# step:142849     episode:380     return:-117    length:77
# step:143281     episode:381     return:-110    length:432
# step:143446     episode:382     return:-138    length:165
# step:143629     episode:383     return:-130    length:183
# step:143823     episode:384     return:-117    length:194
# step:144160     episode:385     return:-120    length:337
# step:144971     episode:386     return:-98     length:811
# step:145299     episode:387     return:-99     length:328
# step:145447     episode:388     return:-126    length:148
# step:146002     episode:389     return:-117    length:555
# step:146184     episode:390     return:-115    length:182
# step:146383     episode:391     return:-129    length:199
# step:146482     episode:392     return:-127    length:99
# step:146814     episode:393     return:-116    length:332
# step:147142     episode:394     return:-121    length:328
# step:147359     episode:395     return:-128    length:217
# step:147763     episode:396     return:-125    length:404
# step:147893     episode:397     return:-135    length:130
# step:148302     episode:398     return:-133    length:409
# step:148778     episode:399     return:-121    length:476
# step:149031     episode:400     return:-105    length:253
# step:149290     episode:401     return:-121    length:259
# step:149370     episode:402     return:-116    length:80
# step:149485     episode:403     return:-132    length:115
# step:149585     episode:404     return:-128    length:100
# step:150754     episode:405     return:-96     length:1169
# step:151012     episode:406     return:-120    length:258
# step:151582     episode:407     return:-92     length:570
# step:152382     episode:408     return:-109    length:800
# step:152660     episode:409     return:-134    length:278
# step:153696     episode:410     return:-137    length:1036
# step:155296     episode:411     return:13      length:1600
# step:155358     episode:412     return:-124    length:62
# step:156228     episode:413     return:-116    length:870
# step:156290     episode:414     return:-120    length:62
# step:156430     episode:415     return:-132    length:140
# step:157937     episode:416     return:-37     length:1507
# step:158052     episode:417     return:-116    length:115
# step:158596     episode:418     return:-98     length:544
# step:160196     episode:419     return:-16     length:1600
# step:161796     episode:420     return:-11     length:1600
# step:163396     episode:421     return:25      length:1600
# step:164996     episode:422     return:17      length:1600
# step:166596     episode:423     return:-11     length:1600
# step:168196     episode:424     return:1       length:1600
# step:169796     episode:425     return:6       length:1600
# step:171396     episode:426     return:67      length:1600
# step:172996     episode:427     return:66      length:1600
# step:174596     episode:428     return:91      length:1600
# step:176196     episode:429     return:79      length:1600
# step:177796     episode:430     return:75      length:1600
# step:177989     episode:431     return:-131    length:193
# step:178516     episode:432     return:-167    length:527
# step:178981     episode:433     return:-162    length:465
# step:180581     episode:434     return:-130    length:1600
# step:182181     episode:435     return:103     length:1600
# step:182302     episode:436     return:-112    length:121
# step:183902     episode:437     return:89      length:1600
# step:185032     episode:438     return:-72     length:1130
# step:185124     episode:439     return:-121    length:92
# step:185257     episode:440     return:-115    length:133
# step:186857     episode:441     return:-115    length:1600
# step:188457     episode:442     return:45      length:1600
# step:190057     episode:443     return:-135    length:1600
# step:191657     episode:444     return:-112    length:1600
# step:193257     episode:445     return:107     length:1600
# step:194447     episode:446     return:-214    length:1190
# step:196047     episode:447     return:-58     length:1600
# step:197647     episode:448     return:-132    length:1600
# step:199247     episode:449     return:-125    length:1600
# step:200847     episode:450     return:46      length:1600
# step:201907     episode:451     return:-33     length:1060
# step:203507     episode:452     return:-101    length:1600
# step:204128     episode:453     return:-71     length:621
# step:204249     episode:454     return:-116    length:121
# step:205849     episode:455     return:190     length:1600
# step:207449     episode:456     return:173     length:1600
# step:209049     episode:457     return:123     length:1600
# step:209159     episode:458     return:-115    length:110
# step:210759     episode:459     return:130     length:1600
# step:212359     episode:460     return:84      length:1600
# step:213959     episode:461     return:63      length:1600
# step:215559     episode:462     return:-77     length:1600
# step:217159     episode:463     return:146     length:1600
# step:218759     episode:464     return:131     length:1600
# step:220359     episode:465     return:116     length:1600
# step:221959     episode:466     return:118     length:1600
# step:223559     episode:467     return:61      length:1600
# step:225159     episode:468     return:84      length:1600
# step:225246     episode:469     return:-110    length:87
# step:225689     episode:470     return:-113    length:443
# step:227289     episode:471     return:-117    length:1600
# step:227573     episode:472     return:-90     length:284
# step:229173     episode:473     return:176     length:1600
# step:229965     episode:474     return:-45     length:792
# step:230105     episode:475     return:-105    length:140
# step:230169     episode:476     return:-122    length:64
# step:230381     episode:477     return:-107    length:212
# step:230753     episode:478     return:-140    length:372
# step:230844     episode:479     return:-114    length:91
# step:231111     episode:480     return:-130    length:267
# step:231216     episode:481     return:-112    length:105
# step:231765     episode:482     return:-90     length:549
# step:232943     episode:483     return:-79     length:1178
# step:233427     episode:484     return:-104    length:484
# step:233745     episode:485     return:-116    length:318
# step:234412     episode:486     return:-136    length:667
# step:234557     episode:487     return:-131    length:145
# step:236157     episode:488     return:141     length:1600
# step:236499     episode:489     return:-122    length:342
# step:236993     episode:490     return:-123    length:494
# step:238593     episode:491     return:141     length:1600
# step:240193     episode:492     return:177     length:1600
# step:241793     episode:493     return:164     length:1600
# step:243393     episode:494     return:177     length:1600
# step:244993     episode:495     return:173     length:1600
# step:245072     episode:496     return:-117    length:79
# step:246074     episode:497     return:13      length:1002
# step:246199     episode:498     return:-118    length:125
# step:247799     episode:499     return:-92     length:1600
# step:249344     episode:500     return:241     length:1545
# step:250438     episode:501     return:36      length:1094
# step:252038     episode:502     return:190     length:1600
# step:253638     episode:503     return:42      length:1600
# step:254705     episode:504     return:-141    length:1067
# step:256305     episode:505     return:139     length:1600
# step:257905     episode:506     return:32      length:1600
# step:259505     episode:507     return:239     length:1600
# step:261105     episode:508     return:156     length:1600
# step:262705     episode:509     return:10      length:1600
# step:264305     episode:510     return:-36     length:1600
# step:265905     episode:511     return:101     length:1600
# step:267505     episode:512     return:77      length:1600
# step:269105     episode:513     return:193     length:1600
# step:270705     episode:514     return:35      length:1600
# step:272254     episode:515     return:251     length:1549
# step:273854     episode:516     return:-58     length:1600
# step:275454     episode:517     return:-27     length:1600
# step:276696     episode:518     return:-126    length:1242
# step:278296     episode:519     return:-46     length:1600
# step:279702     episode:520     return:255     length:1406
# step:281075     episode:521     return:259     length:1373
# step:282584     episode:522     return:248     length:1509
# step:284120     episode:523     return:240     length:1536
# step:285650     episode:524     return:242     length:1530
# step:287005     episode:525     return:262     length:1355
# step:288605     episode:526     return:237     length:1600
# step:290143     episode:527     return:243     length:1538
# step:291657     episode:528     return:246     length:1514
# step:293140     episode:529     return:250     length:1483
# step:294694     episode:530     return:240     length:1554
# step:294853     episode:531     return:-108    length:159
# step:296294     episode:532     return:252     length:1441
# step:297894     episode:533     return:214     length:1600
# step:299366     episode:534     return:249     length:1472
# step:300843     episode:535     return:248     length:1477
# step:300947     episode:536     return:-129    length:104
# step:302490     episode:537     return:244     length:1543
# step:302716     episode:538     return:-116    length:226
# step:303174     episode:539     return:-119    length:458
# step:304545     episode:540     return:252     length:1371
# step:304620     episode:541     return:-125    length:75
# step:306198     episode:542     return:239     length:1578
# step:307654     episode:543     return:246     length:1456
# step:309147     episode:544     return:248     length:1493
# step:310747     episode:545     return:229     length:1600
# step:312256     episode:546     return:73      length:1509
# step:313767     episode:547     return:245     length:1511
# step:315349     episode:548     return:240     length:1582
# step:316949     episode:549     return:240     length:1600
# step:317655     episode:550     return:-28     length:706
# step:318218     episode:551     return:-45     length:563
# step:318648     episode:552     return:-166    length:430
# step:319240     episode:553     return:-66     length:592
# step:319537     episode:554     return:-152    length:297
# step:319919     episode:555     return:-142    length:382
# step:320067     episode:556     return:-125    length:148
# step:320557     episode:557     return:-152    length:490
# step:322120     episode:558     return:245     length:1563
# step:323720     episode:559     return:90      length:1600
# step:323913     episode:560     return:-141    length:193
# step:324315     episode:561     return:-130    length:402
# step:324601     episode:562     return:-67     length:286
# step:324811     episode:563     return:-125    length:210
# step:326411     episode:564     return:220     length:1600
# step:326657     episode:565     return:-149    length:246
# step:327178     episode:566     return:-56     length:521
# step:328778     episode:567     return:225     length:1600
# step:330378     episode:568     return:215     length:1600
# step:331978     episode:569     return:101     length:1600
# step:333578     episode:570     return:131     length:1600
# step:335178     episode:571     return:174     length:1600
# step:336778     episode:572     return:113     length:1600
# step:336886     episode:573     return:-112    length:108
# step:336977     episode:574     return:-113    length:91
# step:337064     episode:575     return:-113    length:87
# step:337164     episode:576     return:-116    length:100
# step:338764     episode:577     return:216     length:1600
# step:339377     episode:578     return:-114    length:613
# step:340975     episode:579     return:235     length:1598
# step:341218     episode:580     return:-115    length:243
# step:342818     episode:581     return:154     length:1600
# step:342949     episode:582     return:-113    length:131
# step:344474     episode:583     return:242     length:1525
# step:344619     episode:584     return:-116    length:145
# step:346075     episode:585     return:246     length:1456
# step:346288     episode:586     return:-117    length:213
# step:347648     episode:587     return:253     length:1360
# step:348205     episode:588     return:-120    length:557
# step:348437     episode:589     return:-127    length:232
# step:348843     episode:590     return:-101    length:406
# step:350182     episode:591     return:255     length:1339
# step:351725     episode:592     return:235     length:1543
# step:353096     episode:593     return:255     length:1371
# step:354566     episode:594     return:245     length:1470
# step:355891     episode:595     return:257     length:1325
# step:357285     episode:596     return:246     length:1394
# step:358729     episode:597     return:246     length:1444
# step:359770     episode:598     return:-136    length:1041
# step:361239     episode:599     return:242     length:1469
# step:362571     episode:600     return:255     length:1332
# step:363887     episode:601     return:258     length:1316
# step:365203     episode:602     return:256     length:1316
# step:366509     episode:603     return:259     length:1306
# step:367856     episode:604     return:254     length:1347
# step:369146     episode:605     return:260     length:1290
# step:370746     episode:606     return:-65     length:1600
# step:372346     episode:607     return:-124    length:1600
# step:373946     episode:608     return:-81     length:1600
# step:375546     episode:609     return:-113    length:1600
# step:377146     episode:610     return:-90     length:1600
# step:378746     episode:611     return:-120    length:1600
# step:380346     episode:612     return:-75     length:1600
# step:381946     episode:613     return:-101    length:1600
# step:383546     episode:614     return:-140    length:1600
# step:385146     episode:615     return:-32     length:1600
# step:386746     episode:616     return:-19     length:1600
# step:387690     episode:617     return:-104    length:944
# step:388833     episode:618     return:-143    length:1143
# step:390433     episode:619     return:21      length:1600
# step:392033     episode:620     return:9       length:1600
# step:393633     episode:621     return:7       length:1600
# step:395233     episode:622     return:-60     length:1600
# step:396833     episode:623     return:-36     length:1600
# step:398433     episode:624     return:71      length:1600
# step:400033     episode:625     return:159     length:1600
# step:401633     episode:626     return:140     length:1600
# step:403233     episode:627     return:151     length:1600
# step:404364     episode:628     return:-97     length:1131
# step:405082     episode:629     return:-26     length:718
# step:406682     episode:630     return:35      length:1600
# step:407813     episode:631     return:-162    length:1131
# step:409069     episode:632     return:267     length:1256
# step:410461     episode:633     return:252     length:1392
# step:410635     episode:634     return:-130    length:174
# step:410784     episode:635     return:-101    length:149
# step:411704     episode:636     return:-145    length:920
# step:412723     episode:637     return:-114    length:1019
# step:414064     episode:638     return:253     length:1341
# step:414338     episode:639     return:-135    length:274
# step:415636     episode:640     return:256     length:1298
# step:417006     episode:641     return:258     length:1370
# step:418222     episode:642     return:270     length:1216
# step:419457     episode:643     return:267     length:1235
# step:420818     episode:644     return:250     length:1361
# step:422035     episode:645     return:-24     length:1217
# step:423487     episode:646     return:-162    length:1452
# step:423718     episode:647     return:-112    length:231
# step:424979     episode:648     return:263     length:1261
# step:426197     episode:649     return:268     length:1218
# step:427797     episode:650     return:232     length:1600
# step:428090     episode:651     return:-92     length:293
# step:428463     episode:652     return:-48     length:373
# step:429205     episode:653     return:-2      length:742
# step:430451     episode:654     return:262     length:1246
# step:431718     episode:655     return:260     length:1267
# step:433318     episode:656     return:-53     length:1600
# step:434189     episode:657     return:-22     length:871
# step:435789     episode:658     return:-33     length:1600
# step:437389     episode:659     return:99      length:1600
# step:438007     episode:660     return:-96     length:618
# step:439563     episode:661     return:-128    length:1556
# step:440179     episode:662     return:-137    length:616
# step:441264     episode:663     return:-121    length:1085
# step:441404     episode:664     return:-118    length:140
# step:442093     episode:665     return:-87     length:689
# step:442394     episode:666     return:-116    length:301
# step:443180     episode:667     return:-121    length:786
# step:443463     episode:668     return:-122    length:283
# step:444539     episode:669     return:-92     length:1076
# step:444676     episode:670     return:-139    length:137
# step:444803     episode:671     return:-132    length:127
# step:445702     episode:672     return:-95     length:899
# step:446925     episode:673     return:265     length:1223
# step:448525     episode:674     return:162     length:1600
# step:449740     episode:675     return:261     length:1215
# step:450997     episode:676     return:254     length:1257
# step:452223     episode:677     return:254     length:1226
# step:453483     episode:678     return:252     length:1260
# step:454738     episode:679     return:254     length:1255
# step:455962     episode:680     return:258     length:1224
# step:457287     episode:681     return:248     length:1325
# step:458887     episode:682     return:210     length:1600
# step:460148     episode:683     return:253     length:1261
# step:461744     episode:684     return:233     length:1596
# step:462909     episode:685     return:261     length:1165
# step:464509     episode:686     return:125     length:1600
# step:465769     episode:687     return:253     length:1260
# step:466684     episode:688     return:61      length:915
# step:467960     episode:689     return:253     length:1276
# step:468325     episode:690     return:-47     length:365
# step:469479     episode:691     return:264     length:1154
# step:470798     episode:692     return:246     length:1319
# step:472166     episode:693     return:248     length:1368
# step:473433     episode:694     return:253     length:1267
# step:474719     episode:695     return:251     length:1286
# step:475951     episode:696     return:257     length:1232
# step:477177     episode:697     return:252     length:1226
# step:478442     episode:698     return:255     length:1265
# step:480042     episode:699     return:210     length:1600
# step:480892     episode:700     return:44      length:850
# step:482267     episode:701     return:238     length:1375
# step:483662     episode:702     return:243     length:1395
# step:485135     episode:703     return:227     length:1473
# step:486521     episode:704     return:240     length:1386
# step:488121     episode:705     return:218     length:1600
# step:488648     episode:706     return:-43     length:527
# step:490248     episode:707     return:165     length:1600
# step:491317     episode:708     return:52      length:1069
# step:492847     episode:709     return:229     length:1530
# step:494111     episode:710     return:253     length:1264
# step:495324     episode:711     return:255     length:1213
# step:496600     episode:712     return:253     length:1276
# step:497875     episode:713     return:252     length:1275
# step:498607     episode:714     return:30      length:732
# step:499893     episode:715     return:254     length:1286
# step:501267     episode:716     return:248     length:1374
#
# Run:0 Training time: _ _ _ _ _9:03:05.304120_ _ _ _ _

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(all_episode_returns[0])+1), all_episode_returns[0], label="Score")
plt.legend(bbox_to_anchor=(1.05, 1)) 
plt.ylabel('Score')
plt.xlabel('Episodes #')
plt.show()

# %%
# Export 1D array to CSV (values along columns)
df_1d = pd.DataFrame(all_episode_returns[0])
df_1d.to_csv('DDPG.csv', index=False, header=False)
